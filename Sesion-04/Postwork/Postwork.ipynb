# %% [markdown]
# Lectura de datos de tasa de conversión de pesos a dólares.

# %%
import pandas as pd

# %%
dfTasaConversionDP = pd.read_excel('../../DataSets/Postwork/1.1.1.TCM_Serie historica IQY.xlsx',
                 skiprows = 7,
                 names=['Fecha (dd/mm/aaaa)', 'Tasa de cambio representativa del mercado (TRM)'])
dfTasaConversionDP
# Out:
#                                       Fecha (dd/mm/aaaa)  \
# 0                                    1991-11-27 00:00:00
# 1                                    1991-11-28 00:00:00
# 2                                    1991-11-29 00:00:00
# 3                                    1991-11-30 00:00:00
# 4                                    1991-12-01 00:00:00
# ...                                                  ...
# 11016                                2022-01-24 00:00:00
# 11017                                                NaN
# 11018  Fuente: Superintendencia Financiera de Colombi...
# 11019                                                NaN
# 11020   Banco de la República - Gerencia Técnica - in...
#
#        Tasa de cambio representativa del mercado (TRM)
# 0                                               693.32
# 1                                               693.99
# 2                                               694.70
# 3                                               694.70
# ...

# %%
dfTasaConversionDP.shape
# Out:
# (11021, 2)

# %%
dfTasaConversionDP.dtypes
# Out:
# Fecha (dd/mm/aaaa)                                  object
# Tasa de cambio representativa del mercado (TRM)    float64
# dtype: object

# %%
dfTasaConversionDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11021 entries, 0 to 11020
# Data columns (total 2 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Fecha (dd/mm/aaaa)                               11019 non-null  object
#  1   Tasa de cambio representativa del mercado (TRM)  11017 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 172.3+ KB

# %%
dfTasaConversionDP.columns
# Out:
# Index(['Fecha (dd/mm/aaaa)', 'Tasa de cambio representativa del mercado (TRM)'], dtype='object')

# %%
dfTasaConversionDP.head()
# Out:
#     Fecha (dd/mm/aaaa)  Tasa de cambio representativa del mercado (TRM)
# 0  1991-11-27 00:00:00                                           693.32
# 1  1991-11-28 00:00:00                                           693.99
# 2  1991-11-29 00:00:00                                           694.70
# 3  1991-11-30 00:00:00                                           694.70
# 4  1991-12-01 00:00:00                                           643.42

# %%
dfTasaConversionDP.tail()
# Out:
#                                       Fecha (dd/mm/aaaa)  \
# 11016                                2022-01-24 00:00:00
# 11017                                                NaN
# 11018  Fuente: Superintendencia Financiera de Colombi...
# 11019                                                NaN
# 11020   Banco de la República - Gerencia Técnica - in...
#
#        Tasa de cambio representativa del mercado (TRM)
# 11016                                           3964.3
# 11017                                              NaN
# 11018                                              NaN
# 11019                                              NaN
# 11020                                              NaN

# %% [markdown]
# Conclusiones
# 1. Los datos son suficientes para realizar el análisis
# 2. Se deben renombrar las columnas para facilitar su consulta
# 3. Los tipos de datos no corresponden a los que deberían ser.
# 4. Existen datos en las últimas filas que no corresponden a los que se necesitan
# 5. Los datos son diarios

# %% [markdown]
# Lectura de datos de inflación.

# %%
dfInflacion = pd.read_excel('../../DataSets/Postwork/1.2.5.IPC_Serie_variaciones.xlsx',
                 skiprows = 12,)
dfInflacion
# Out:
#                                      Año(aaaa)-Mes(mm)  Índice  \
# 0                                             195407.0    0.03
# 1                                             195408.0    0.03
# 2                                             195409.0    0.03
# 3                                             195410.0    0.03
# 4                                             195411.0    0.03
# ..                                                 ...     ...
# 811  1 / La inflación se define como la variación p...     NaN
# 812                                                NaN     NaN
# 813   Fuente: Departamento Administrativo Nacional ...     NaN
# 814                                                        NaN
# 815   Banco de la República - Gerencia Técnica - in...     NaN
#
#      Inflación anual %  Inflación mensual %  Inflación año corrido %
# 0                  NaN                  NaN                      NaN
# 1                  NaN                -0.76                    -0.76
# ...

# %%
dfInflacion.shape
# Out:
# (816, 5)

# %%
dfInflacion.dtypes
# Out:
# Año(aaaa)-Mes(mm)           object
# Índice                     float64
# Inflación anual %          float64
# Inflación mensual %        float64
# Inflación año corrido %    float64
# dtype: object

# %%
dfInflacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Año(aaaa)-Mes(mm)        814 non-null    object
#  1   Índice                   810 non-null    float64
#  2   Inflación anual %        798 non-null    float64
#  3   Inflación mensual %      809 non-null    float64
#  4   Inflación año corrido %  809 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 32.0+ KB

# %%
dfInflacion.columns
# Out:
# Index(['Año(aaaa)-Mes(mm)', 'Índice', 'Inflación anual %',
#        'Inflación mensual %', 'Inflación año corrido %'],
#       dtype='object')

# %%
dfInflacion.head()
# Out:
#   Año(aaaa)-Mes(mm)  Índice  Inflación anual %  Inflación mensual %  \
# 0          195407.0    0.03                NaN                  NaN
# 1          195408.0    0.03                NaN                -0.76
# 2          195409.0    0.03                NaN                -1.37
# 3          195410.0    0.03                NaN                 0.34
# 4          195411.0    0.03                NaN                 0.27
#
#    Inflación año corrido %
# 0                      NaN
# 1                    -0.76
# 2                    -2.12
# 3                    -1.79
# 4                    -1.52

# %%
dfInflacion.tail()
# Out:
#                                      Año(aaaa)-Mes(mm)  Índice  \
# 811  1 / La inflación se define como la variación p...     NaN
# 812                                                NaN     NaN
# 813   Fuente: Departamento Administrativo Nacional ...     NaN
# 814                                                        NaN
# 815   Banco de la República - Gerencia Técnica - in...     NaN
#
#      Inflación anual %  Inflación mensual %  Inflación año corrido %
# 811                NaN                  NaN                      NaN
# 812                NaN                  NaN                      NaN
# 813                NaN                  NaN                      NaN
# 814                NaN                  NaN                      NaN
# 815                NaN                  NaN                      NaN

# %% [markdown]
# Conclusiones
# 1. Los datos son suficientes para realizar el análisis
# 2. Se deben renombrar las columnas para facilitar su consulta
# 3. Los tipos de datos no corresponden a los que deberían ser.
# 4. Existen datos en las últimas filas que no corresponden a los que se necesitan
# 5. Los datos son mensuales
# 6. Es posible que no se necesiten todas las columna

# %%
dfSalarioMinimo = pd.read_excel('../../DataSets/Postwork/articles-388408_recurso_1.xlsx',
                 skiprows = 5,)
dfSalarioMinimo
# Out:
#                                                   Año  Salario mínimo diario  \
# 0                                                1984                 376.60
# 1                                                1985                 451.92
# 2                                                1986                 560.38
# 3                                                1987                 683.66
# 4                                                1988                 854.58
# 5                                                1989                1085.32
# 6                                                1990                1367.50
# 7                                                1991                1724.00
# 8                                                1992                2173.00
# 9                                                1993                2717.00
# 10                                               1994                3290.00
# ...

# %%
dfSalarioMinimo.shape
# Out:
# (49, 5)

# %%
dfSalarioMinimo.dtypes
# Out:
# Año                                object
# Salario mínimo diario             float64
# Salario mínimo mensual            float64
# Variación porcentual anual %      float64
# Decretos del Gobierno Nacional     object
# dtype: object

# %%
dfSalarioMinimo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Año                             43 non-null     object
#  1   Salario mínimo diario           38 non-null     float64
#  2   Salario mínimo mensual          38 non-null     float64
#  3   Variación porcentual anual %    37 non-null     float64
#  4   Decretos del Gobierno Nacional  38 non-null     object
# dtypes: float64(3), object(2)
# memory usage: 2.0+ KB

# %%
dfSalarioMinimo.columns
# Out:
# Index(['Año', 'Salario mínimo diario', 'Salario mínimo mensual',
#        'Variación porcentual anual %', 'Decretos del Gobierno Nacional'],
#       dtype='object')

# %%
dfSalarioMinimo.head()
# Out:
#     Año  Salario mínimo diario  Salario mínimo mensual  \
# 0  1984                 376.60                 11298.0
# 1  1985                 451.92                 13558.0
# 2  1986                 560.38                 16811.0
# 3  1987                 683.66                 20510.0
# 4  1988                 854.58                 25637.0
#
#    Variación porcentual anual % Decretos del Gobierno Nacional
# 0                           NaN   3506 de diciembre 27 de 1983
# 1                          20.0         0001 de enero de 1985
# 2                          24.0     3754 de diciembre de 1985
# 3                          22.0     3732 de diciembre de 1986
# 4                          25.0     2545 de diciembre de 1987

# %%
dfSalarioMinimo.tail()
# Out:
#                                                   Año  Salario mínimo diario  \
# 44   ¹ Variación porcentual con respecto al dato d...                    NaN
# 45                                                NaN                    NaN
# 46                                   (N/A)  No aplica                    NaN
# 47                                                NaN                    NaN
# 48   Banco de la República - Gerencia Técnica - in...                    NaN
#
#     Salario mínimo mensual  Variación porcentual anual %  \
# 44                     NaN                           NaN
# 45                     NaN                           NaN
# 46                     NaN                           NaN
# 47                     NaN                           NaN
# 48                     NaN                           NaN
#
#    Decretos del Gobierno Nacional
# 44                            NaN
# 45                            NaN
# 46                            NaN
# ...

# %% [markdown]
# Conclusiones
# 1. Los datos son suficientes para realizar el análisis
# 2. Se deben renombrar las columnas para facilitar su consulta
# 3. Los tipos de datos no corresponden a los que deberían ser.
# 4. Existen datos en las últimas filas que no corresponden a los que se necesitan
# 5. Los datos son anuales
# 6. Es posible que no se necesiten todas las columna
