# %% [markdown]
# ## Ejemplo 5: Concat con DataFrames
#
# ### 1. Objetivos:
#     - Usar pd.concat para concatenar `DataFrames`
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# Exactamente los mismos principios aplican a la concatenación de `DataFrames`

# %%
import pandas as pd

# %% [markdown]
# Considera los siguientes dos DataFrames:

# %%
data_1 = {
    'column_1': [1, 2, 3],
    'column_2': [4, 5, 6]
}

df_1 = pd.DataFrame(data_1, index=['a', 'b', 'c'])
df_1
# Out:
#    column_1  column_2
# a         1         4
# b         2         5
# c         3         6

# %%
data_2 = {
    'column_1': [7, 8, 9],
    'column_2': [10, 11, 12]
}

df_2 = pd.DataFrame(data_2, index=['d', 'e', 'f'])
df_2
# Out:
#    column_1  column_2
# d         7        10
# e         8        11
# f         9        12

# %% [markdown]
# Para unirlos verticalmente usamos:
#
# `pd.concat(-lista de dataframes-, axis=0)`

# %%
df = pd.concat([df_1, df_2])
df
# Out:
#    column_1  column_2
# a         1         4
# b         2         5
# c         3         6
# d         7        10
# e         8        11
# f         9        12

# %% [markdown]
# Horizontalmente con `axis=1`:

# %%
pd.concat([df_1, df_2], axis=1)
# Out:
#    column_1  column_2  column_1  column_2
# a       1.0       4.0       NaN       NaN
# b       2.0       5.0       NaN       NaN
# c       3.0       6.0       NaN       NaN
# d       NaN       NaN       7.0      10.0
# e       NaN       NaN       8.0      11.0
# f       NaN       NaN       9.0      12.0

# %% [markdown]
# Si dos DataFrames tienen el mismo índice, evitamos los `NaNs`:

# %%
data_3 = {
    'column_3': [7, 8, 9],
    'column_4': [10, 11, 12]
}

df_3 = pd.DataFrame(data_3, index=['a', 'b', 'c'])
df_3
# Out:
#    column_3  column_4
# a         7        10
# b         8        11
# c         9        12

# %% [markdown]
# Concatenamos los DataFrames 1 y 3 en horizontal:

# %%
pd.concat([df_1, df_3])
# Out:
#    column_1  column_2  column_3  column_4
# a       1.0       4.0       NaN       NaN
# b       2.0       5.0       NaN       NaN
# c       3.0       6.0       NaN       NaN
# a       NaN       NaN       7.0      10.0
# b       NaN       NaN       8.0      11.0
# c       NaN       NaN       9.0      12.0

# %% [markdown]
# Si concatenamos verticalmente con el mismo índice, no podemos diferenciarlos:

# %%
data_4 = {
    'column_1': [7, 8, 9],
    'column_2': [10, 11, 12]
}

df_4 = pd.DataFrame(data_4, index=['a', 'b', 'c'])
df_4
# Out:
#    column_1  column_2
# a         7        10
# b         8        11
# c         9        12

# %% [markdown]
# Concatenamos los DataFrames 1 y 4 en vertical (`axis=0`):

# %%
pd.concat([df_1, df_4])
# Out:
#    column_1  column_2
# a         1         4
# b         2         5
# c         3         6
# a         7        10
# b         8        11
# c         9        12

# %% [markdown]
# Podemos agregar multi índices `df_1` y `df_4` haciendo uso de
#
# `keys=-lista de índices-`:

# %%
df = pd.concat([df_1, df_4], keys=["df_1","df_4"])
df
# Out:
#         column_1  column_2
# df_1 a         1         4
#      b         2         5
#      c         3         6
# df_4 a         7        10
#      b         8        11
#      c         9        12

# %% [markdown]
# Y podemos accesarlos de igual manera, imprime los elementos del dataframe con etiqueta `df_1` usando la forma `df.loc[-etiqueta-]`:

# %%
df.loc["df_1"]
# Out:
#    column_1  column_2
# a         1         4
# b         2         5
# c         3         6

# %% [markdown]
# Ahora imprime la fila `b` del dataframe `df_4` usando la forma `df.loc[(-etiqueta 1-, -etiqueta 2-)]`:

# %%
df.loc["df_4", "b"]
# Out:
# column_1     8
# column_2    11
# Name: (df_4, b), dtype: int64

# %% [markdown]
# ¿Y si quicieramos la columna_2 de la fila b del dataframe df_4?

# %%
df
# Out:
#         column_1  column_2
# df_1 a         1         4
#      b         2         5
#      c         3         6
# df_4 a         7        10
#      b         8        11
#      c         9        12

# %%
df.loc[("df_4", "b"), "column_2"]
# Out:
# 11

# %%
df.loc[("df_4", "b"), ["column_2"]]
# Out:
# column_2    11
# Name: (df_4, b), dtype: int64

# %% [markdown]
# También podemos unir más de dos `DataFrames` agregándolos todos a la lista, recuerda la forma `pd.concat(-lista de dataframes-, axis=1)`, con `axis=1` la concatenación es por columnas, entonces vamos a unir los dataframes `df_1`, `df_2`, `df_3` y `df_4` en dirección horizontal:

# %%
df_5 = pd.concat([df_1, df_2, df_3, df_4], axis=1)
df_5
# Out:
#    column_1  column_2  column_1  column_2  column_3  column_4  column_1  \
# a       1.0       4.0       NaN       NaN       7.0      10.0       7.0
# b       2.0       5.0       NaN       NaN       8.0      11.0       8.0
# c       3.0       6.0       NaN       NaN       9.0      12.0       9.0
# d       NaN       NaN       7.0      10.0       NaN       NaN       NaN
# e       NaN       NaN       8.0      11.0       NaN       NaN       NaN
# f       NaN       NaN       9.0      12.0       NaN       NaN       NaN
#
#    column_2
# a      10.0
# b      11.0
# c      12.0
# d       NaN
# e       NaN
# f       NaN

# %%
df_5.loc[:, "column_1"]
# Out:
#    column_1  column_1  column_1
# a       1.0       NaN       7.0
# b       2.0       NaN       8.0
# c       3.0       NaN       9.0
# d       NaN       7.0       NaN
# e       NaN       8.0       NaN
# f       NaN       9.0       NaN

# %%
df_6 = pd.concat([df_1, df_2, df_3, df_4], axis=1, keys=["df_1","df_2","df_3","df_4"])
df_6
# Out:
#       df_1              df_2              df_3              df_4
#   column_1 column_2 column_1 column_2 column_3 column_4 column_1 column_2
# a      1.0      4.0      NaN      NaN      7.0     10.0      7.0     10.0
# b      2.0      5.0      NaN      NaN      8.0     11.0      8.0     11.0
# c      3.0      6.0      NaN      NaN      9.0     12.0      9.0     12.0
# d      NaN      NaN      7.0     10.0      NaN      NaN      NaN      NaN
# e      NaN      NaN      8.0     11.0      NaN      NaN      NaN      NaN
# f      NaN      NaN      9.0     12.0      NaN      NaN      NaN      NaN

# %%
df_7 = pd.concat([df_1, df_2, df_3, df_4], axis=0, keys=["df_1","df_2","df_3","df_4"])
df_7
# Out:
#         column_1  column_2  column_3  column_4
# df_1 a       1.0       4.0       NaN       NaN
#      b       2.0       5.0       NaN       NaN
#      c       3.0       6.0       NaN       NaN
# df_2 d       7.0      10.0       NaN       NaN
#      e       8.0      11.0       NaN       NaN
#      f       9.0      12.0       NaN       NaN
# df_3 a       NaN       NaN       7.0      10.0
#      b       NaN       NaN       8.0      11.0
#      c       NaN       NaN       9.0      12.0
# df_4 a       7.0      10.0       NaN       NaN
#      b       8.0      11.0       NaN       NaN
#      c       9.0      12.0       NaN       NaN

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reto 5: Concatenación de `Series` y `DataFrames`
#
# ### 1. Objetivos:
#     - Practicar la concatenación de `Series` y `DataFrames` usando `np.concat` y `pandas.DataFrame.append`
#
# ### 2. Desarrollo:

# %% [markdown]
# ### a) Sumando ventas por producto y por mes
#
# Eres el analista financiero de EyePoker Inc. Tienes 12 listas con datos. Cada lista contiene la cantidad de unidades vendidas por producto en un mes determinado.
#
# Tienes también una lista con los nombres de los productos que ofrece la empresa.
#
# Tanto las listas de ventas como la lista de nombres están ordenadas igual. Eso quiere decir que cada índice de cada lista pertenece a datos del mismo producto (es decir, `ventas_enero[3]`, `ventas_febrero[3]`, `ventas_marzo[3]`, `ventas_abril[3]`, etc, todas pertenecen al producto en `productos[3]`).
#
# Tu reto es el siguiente:
#
# 1. Convierte las listas en `Series` de pandas.
# 2. Concatena horizontalmente las `Series` de ventas de manera que cada fila del `DataFrame` resultante corresponda al mismo producto.
# 3. En alguno de los pasos anteriores, agrega los nombres de los productos como índice.
# 4. Crea una nueva columna llamada `total_por_producto` que contenga la suma horizontal de las ventas mensuales de cada producto (es decir, un resumen de las ventas del año por producto).
# 5. Agrega también una fila hasta el final que tenga como índice `total_por_mes` que contenga la suma vertical de las ventas de cada mes (la última celda va a ser la suma total de las ventas de todos los productos en todo el año).
#
# > **Tip**: Para hacer el paso número 5, busca en Google el método `pandas.DataFrame.append`.

# %%
productos = ["Pokemaster", "Cegatron", "Pikame Mucho",
    "Lazarillo de Tormes", "Stevie Wonder", "Needle",
    "El AyMeDuele", "El Desretinador", "Sacamel Ojocles",
    "Desojado", "Maribel Buenas Noches", "Cíclope",
    "El Cuatro Ojos"]

ventas_enero = [3, 5, 4, 45, 2, 32, 7, 89, 7, 6, 24, 51, 12]
ventas_febrero = [7, 9, 0, 76, 4, 34, 1, 2, 34, 67, 8, 9, 0]
ventas_marzo = [1, 1, 3, 56, 7, 98, 2, 34, 1, 0, 23, 1, 12]
ventas_abril = [2, 34, 2, 1, 56, 78, 23, 3, 4, 23, 1, 78, 9]
ventas_mayo = [1, 2, 32, 4, 32, 1, 45, 67, 87, 8, 9, 45, 2]
ventas_junio = [1, 2, 32, 1, 45, 78, 8, 90, 0, 98, 7, 46, 15]
ventas_julio = [15, 62, 37, 85, 5, 8, 9, 0, 75, 36, 52, 15, 12]
ventas_agosto = [1, 2, 32, 4, 35, 6, 78, 43, 45, 12, 34, 67, 89]
ventas_septiembre = [9, 87, 7, 6, 56, 7, 0, 34, 23, 1, 2, 51, 35]
ventas_octubre = [16, 62, 75, 58, 97, 6, 9, 0, 98, 78, 2, 3, 4]
ventas_noviembre = [1, 3, 2, 1, 4, 5, 2, 4, 7, 8, 4, 3, 5]
ventas_diciembre = [7, 9, 0, 6, 3, 7, 3, 85, 9, 7, 8, 0, 9]

# %% [markdown]
# Asigna tu resultado final a la variable de la siguiente celda:

# %%
ventas_meses = []
meses = ["enero", "febrero", "marzo", "abril", "mayo", "junio", "julio", "agosto", "septiembre", "octubre", "noviembre", "diciembre"]

ventas_meses.append(pd.Series(ventas_enero, index=productos))
ventas_meses.append(pd.Series(ventas_febrero, index=productos))
ventas_meses.append(pd.Series(ventas_marzo, index=productos))
ventas_meses.append(pd.Series(ventas_abril, index=productos))
ventas_meses.append(pd.Series(ventas_mayo, index=productos))
ventas_meses.append(pd.Series(ventas_junio, index=productos))
ventas_meses.append(pd.Series(ventas_julio, index=productos))
ventas_meses.append(pd.Series(ventas_agosto, index=productos))
ventas_meses.append(pd.Series(ventas_septiembre, index=productos))
ventas_meses.append(pd.Series(ventas_octubre, index=productos))
ventas_meses.append(pd.Series(ventas_noviembre, index=productos))
ventas_meses.append(pd.Series(ventas_diciembre, index=productos))

ventas_dataframe = pd.concat(ventas_meses, axis=1, keys=meses)
ventas_dataframe["total_por_producto"] = ventas_dataframe.sum(axis=1) 

total_por_mes_s = ventas_dataframe.sum() 
total_por_mes_s.name = "total_por_mes"

ventas_dataframe = ventas_dataframe.append(total_por_mes_s)

ventas_dataframe
# Out:
#                        enero  febrero  marzo  abril  mayo  junio  julio  \
# Pokemaster                 3        7      1      2     1      1     15
# Cegatron                   5        9      1     34     2      2     62
# Pikame Mucho               4        0      3      2    32     32     37
# Lazarillo de Tormes       45       76     56      1     4      1     85
# Stevie Wonder              2        4      7     56    32     45      5
# Needle                    32       34     98     78     1     78      8
# El AyMeDuele               7        1      2     23    45      8      9
# El Desretinador           89        2     34      3    67     90      0
# Sacamel Ojocles            7       34      1      4    87      0     75
# Desojado                   6       67      0     23     8     98     36
# Maribel Buenas Noches     24        8     23      1     9      7     52
# Cíclope                   51        9      1     78    45     46     15
# El Cuatro Ojos            12        0     12      9     2     15     12
# total_por_mes            287      251    239    314   335    423    411
#
#                        agosto  septiembre  octubre  noviembre  diciembre  \
# Pokemaster                  1           9       16          1          7
# Cegatron                    2          87       62          3          9
# Pikame Mucho               32           7       75          2          0
# Lazarillo de Tormes         4           6       58          1          6
# Stevie Wonder              35          56       97          4          3
# Needle                      6           7        6          5          7
# El AyMeDuele               78           0        9          2          3
# El Desretinador            43          34        0          4         85
# Sacamel Ojocles            45          23       98          7          9
# Desojado                   12           1       78          8          7
# Maribel Buenas Noches      34           2        2          4          8
# Cíclope                    67          51        3          3          0
# El Cuatro Ojos             89          35        4          5          9
# total_por_mes             448         318      508         49        153
#
#                        total_por_producto
# Pokemaster                             64
# Cegatron                              278
# Pikame Mucho                          226
# Lazarillo de Tormes                   343
# Stevie Wonder                         346
# Needle                                360
# El AyMeDuele                          187
# El Desretinador                       451
# Sacamel Ojocles                       390
# Desojado                              344
# Maribel Buenas Noches                 174
# Cíclope                               369
# El Cuatro Ojos                        204
# total_por_mes                        3736

# %% [markdown]
# A continuación la celda de validación ...

# %%
import base64
from pprint import pprint

def revisar_dataframe(ventas_dataframe, productos, ventas_enero, ventas_febrero, ventas_marzo, ventas_abril, ventas_mayo,
                      ventas_junio, ventas_julio, ventas_agosto, ventas_septiembre,
                      ventas_octubre, ventas_noviembre, ventas_diciembre):
    
    import pandas as pd
    
    data_1 = b'...'
    
    eval(compile(base64.b64decode(data_1).decode("utf-8"), "", "exec"), globals())
    ventas_dataframe_2 = concatenar_listas_horizontalmente([ventas_enero, ventas_febrero, ventas_marzo, ventas_abril, ventas_mayo,
                                                      ventas_junio, ventas_julio, ventas_agosto, ventas_septiembre,
                                                      ventas_octubre, ventas_noviembre, ventas_diciembre], productos)
    ventas_dataframe_2['total_por_producto'] = ventas_dataframe_2.sum(axis=1)
    total_por_mes = ventas_dataframe_2.sum(axis=0)
    total_por_mes.name = 'total_por_mes'
    ventas_dataframe_2 = ventas_dataframe_2.append(total_por_mes)
    
    if ventas_dataframe.equals(ventas_dataframe_2):
        print(f'Felicidades! El procedimiento fue realizado correctamente.')
        import seaborn as sns
        import matplotlib.pyplot as plt
        
        fig, axs = plt.subplots(2, 1, figsize=(8, 12))
        sin_total_por_mes = ventas_dataframe.drop(index='total_por_mes')
        sin_total_por_mes.sort_values('total_por_producto', ascending=False, inplace=True)
        axs[0].set_title('Ventas totales por producto')
        sns.barplot(sin_total_por_mes['total_por_producto'], sin_total_por_mes.index, ax=axs[0])
        
        axs[1].set_title('Ventas totales por mes')
        sin_total_por_producto = ventas_dataframe.drop(columns='total_por_producto')
        sns.barplot(sin_total_por_producto.columns, sin_total_por_producto.loc['total_por_mes'], orient='v', ax=axs[1])
        for item in axs[1].get_xticklabels():
            item.set_rotation(45)
        
    else:
        from IPython.display import display
        print(f'Hubo un error!\n')
        print('Dataframe esperado:')
        display(ventas_dataframe_2)
        print('\nDataframe recibido:')
        display(ventas_dataframe)
        
revisar_dataframe(ventas_dataframe, productos, ventas_enero, ventas_febrero, ventas_marzo, ventas_abril, ventas_mayo,
                      ventas_junio, ventas_julio, ventas_agosto, ventas_septiembre,
                      ventas_octubre, ventas_noviembre, ventas_diciembre)
# Out:
# Felicidades! El procedimiento fue realizado correctamente.
# c:\users\hborda\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\hborda\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
