# %% [markdown]
# ## Ejemplo 6: Automatizando peticiones
#
# ### 1. Objetivos:
#     - Usar todo lo que aprendimos para automatizar peticiones al API
#     - Guardar nuestros resultados en un archivo tipo .csv
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# Veamos cómo usar todo lo que aprendimos para automatizar el proceso de realizar múltiples peticiones a la API, reunirlas en un `DataFrame` y guardarlo en un .csv:

# %%
import pandas as pd
import requests

# %%
url = 'https://api.nasa.gov/neo/rest/v1/neo/browse/'
parametros = {
    'api_key': 'y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW'
}

# %% [markdown]
# Obtener 1 página de datos del API.

# %%
resultados = requests.get(url, params=parametros)
if resultados.status_code == 200:
    datos = resultados.json() # regresa un diccionario
    objetos = datos["near_earth_objects"] # se obtienen 20 objetos por página
    url = datos["links"]["next"]
    parametros = {}
else:
    print("Error en la petición de requests")
# Out:
# 200

# %% [markdown]
# Obtener 10 páginas de datos del API.

# %%
url = 'https://api.nasa.gov/neo/rest/v1/neo/browse/'
parametros = {
    'api_key': 'y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW'
}
paginas_objetos = []
for _ in range(20):
    resultados = requests.get(url, params=parametros)
    if resultados.status_code == 200:
        datos = resultados.json() # regresa un diccionario
        objetos = datos["near_earth_objects"] # se obtienen 20 objetos por página
        paginas_objetos.append(objetos)
        
        url = datos["links"]["next"]
        parametros = {}
        
        print(datos["links"]["self"])
    else:
        print("Error en la petición de requests")
# Out:
# http://www.neowsapp.com/rest/v1/neo/browse?page=0&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=1&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=2&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=3&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=4&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=5&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=6&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=7&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=8&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=9&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=10&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=11&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=12&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=13&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=14&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=15&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=16&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=17&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=18&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW
# http://www.neowsapp.com/rest/v1/neo/browse?page=19&size=20&api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW

# %% [markdown]
# Valiando la cantidad de diccionarios obtenidos:

# %%
len(paginas_objetos)
# Out:
# 20

# %% [markdown]
# Validando el tipo de dato del elemento 0 de la lista:

# %%
type(paginas_objetos[0])
# Out:
# list

# %%
len(paginas_objetos[0])
# Out:
# 20

# %%
type(paginas_objetos[0][0])
# Out:
# dict

# %% [markdown]
# Normalizar y crea los dataframes usando `map` o listas de compresión:

# %%
pd.json_normalize(paginas_objetos[0]).head(3)
# Out:
#         id neo_reference_id                  name name_limited designation  \
# 0  2000433          2000433    433 Eros (A898 PA)         Eros         433
# 1  2000719          2000719  719 Albert (A911 TB)       Albert         719
# 2  2000887          2000887  887 Alinda (A918 AA)       Alinda         887
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                 10.43
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                 15.51
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                 13.87
#
#    is_potentially_hazardous_asteroid  \
# 0                              False
# 1                              False
# 2                              False
#
#                                  close_approach_data  is_sentry_object  ...  \
# 0  [{'close_approach_date': '1900-12-27', 'close_...             False  ...
# 1  [{'close_approach_date': '1909-08-21', 'close_...             False  ...
# 2  [{'close_approach_date': '1910-01-04', 'close_...             False  ...
#
#   orbital_data.perihelion_distance  orbital_data.perihelion_argument  \
# 0                1.133475820116491                 178.8971619902451
# 1                1.194898892415675                 156.2275765643465
# 2                1.062256387810841                 350.4932417946612
#
#    orbital_data.aphelion_distance  orbital_data.perihelion_time  \
# 0                1.78307038061344          2459802.569605474861
# 1               4.080111812929026          2459956.011943464095
# 2               3.884059710445925          2459258.734847818714
#
#    orbital_data.mean_anomaly  orbital_data.mean_motion  orbital_data.equinox  \
# 0          246.9041236220357         .5596877180622503                 J2000
# 1          278.1971857577304         .2300986387269753                 J2000
# 2          86.60720939790032         .2534114693822276                 J2000
#
#    orbital_data.orbit_class.orbit_class_type  \
# 0                                        AMO
# 1                                        AMO
# 2                                        AMO
#
#     orbital_data.orbit_class.orbit_class_description  \
# 0  Near-Earth asteroid orbits similar to that of ...
# 1  Near-Earth asteroid orbits similar to that of ...
# 2  Near-Earth asteroid orbits similar to that of ...
#
#   orbital_data.orbit_class.orbit_class_range
# 0         1.017 AU < q (perihelion) < 1.3 AU
# 1         1.017 AU < q (perihelion) < 1.3 AU
# 2         1.017 AU < q (perihelion) < 1.3 AU
#
# [3 rows x 44 columns]

# %%
dfs = [pd.json_normalize(pagina) for pagina in paginas_objetos]

# %% [markdown]
# Valida el tipo de dato del elemento 0:

# %%
dfs[0].head(3)
# Out:
#         id neo_reference_id                  name name_limited designation  \
# 0  2000433          2000433    433 Eros (A898 PA)         Eros         433
# 1  2000719          2000719  719 Albert (A911 TB)       Albert         719
# 2  2000887          2000887  887 Alinda (A918 AA)       Alinda         887
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                 10.43
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                 15.51
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                 13.87
#
#    is_potentially_hazardous_asteroid  \
# 0                              False
# 1                              False
# 2                              False
#
#                                  close_approach_data  is_sentry_object  ...  \
# 0  [{'close_approach_date': '1900-12-27', 'close_...             False  ...
# 1  [{'close_approach_date': '1909-08-21', 'close_...             False  ...
# 2  [{'close_approach_date': '1910-01-04', 'close_...             False  ...
#
#   orbital_data.perihelion_distance  orbital_data.perihelion_argument  \
# 0                1.133475820116491                 178.8971619902451
# 1                1.194898892415675                 156.2275765643465
# 2                1.062256387810841                 350.4932417946612
#
#    orbital_data.aphelion_distance  orbital_data.perihelion_time  \
# 0                1.78307038061344          2459802.569605474861
# 1               4.080111812929026          2459956.011943464095
# 2               3.884059710445925          2459258.734847818714
#
#    orbital_data.mean_anomaly  orbital_data.mean_motion  orbital_data.equinox  \
# 0          246.9041236220357         .5596877180622503                 J2000
# 1          278.1971857577304         .2300986387269753                 J2000
# 2          86.60720939790032         .2534114693822276                 J2000
#
#    orbital_data.orbit_class.orbit_class_type  \
# 0                                        AMO
# 1                                        AMO
# 2                                        AMO
#
#     orbital_data.orbit_class.orbit_class_description  \
# 0  Near-Earth asteroid orbits similar to that of ...
# 1  Near-Earth asteroid orbits similar to that of ...
# 2  Near-Earth asteroid orbits similar to that of ...
#
#   orbital_data.orbit_class.orbit_class_range
# 0         1.017 AU < q (perihelion) < 1.3 AU
# 1         1.017 AU < q (perihelion) < 1.3 AU
# 2         1.017 AU < q (perihelion) < 1.3 AU
#
# [3 rows x 44 columns]

# %% [markdown]
# Explora el inicio del dataframe del elemento 0:

# %%
dfs[-1].head(3)
# Out:
#         id neo_reference_id               name designation  \
# 0  2089136          2089136  89136 (2001 US16)       89136
# 1  2089355          2089355  89355 (2001 VS78)       89355
# 2  2089830          2089830    89830 (2002 CE)       89830
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2089136                 20.20
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2089355                 15.78
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2089830                 14.96
#
#    is_potentially_hazardous_asteroid  \
# 0                               True
# 1                              False
# 2                               True
#
#                                  close_approach_data  is_sentry_object  \
# 0  [{'close_approach_date': '1903-04-01', 'close_...             False
# 1  [{'close_approach_date': '1904-02-14', 'close_...             False
# 2  [{'close_approach_date': '1932-09-20', 'close_...             False
#
#                                           links.self  ...  \
# 0  http://www.neowsapp.com/rest/v1/neo/2089136?ap...  ...
# 1  http://www.neowsapp.com/rest/v1/neo/2089355?ap...  ...
# 2  http://www.neowsapp.com/rest/v1/neo/2089830?ap...  ...
#
#    orbital_data.perihelion_argument  orbital_data.aphelion_distance  \
# 0                 67.16433330747834               1.698988713101187
# 1                  84.9285289319772               2.337924441266135
# 2                 5.803783799038603               3.130691646775495
#
#    orbital_data.perihelion_time  orbital_data.mean_anomaly  \
# 0          2459490.891931987204          68.40628981094495
# 1          2459328.415973878733          112.2348425197834
# 2          2459830.780883668855          284.1859465383844
#
#    orbital_data.mean_motion  orbital_data.equinox  \
# 0         .6240990380649638                 J2000
# 1          .412500667972917                 J2000
# 2         .3292242597550415                 J2000
#
#    orbital_data.orbit_class.orbit_class_type  \
# 0                                        APO
# 1                                        AMO
# 2                                        AMO
#
#     orbital_data.orbit_class.orbit_class_description  \
# 0  Near-Earth asteroid orbits which cross the Ear...
# 1  Near-Earth asteroid orbits similar to that of ...
# 2  Near-Earth asteroid orbits similar to that of ...
#
#           orbital_data.orbit_class.orbit_class_range name_limited
# 0  a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
# 1                 1.017 AU < q (perihelion) < 1.3 AU          NaN
# 2                 1.017 AU < q (perihelion) < 1.3 AU          NaN
#
# [3 rows x 44 columns]

# %% [markdown]
# Concatena los dataframes en un sólo dataframe y reinicia índices (por alguna buena razón hemos creado una lista de dataframes ¿cierto?):

# %%
df = pd.concat(dfs)
df_1 = df.reset_index(drop=True)
df_1
# Out:
#           id neo_reference_id                    name name_limited  \
# 0    2000433          2000433      433 Eros (A898 PA)         Eros
# 1    2000719          2000719    719 Albert (A911 TB)       Albert
# 2    2000887          2000887    887 Alinda (A918 AA)       Alinda
# 3    2001036          2001036  1036 Ganymed (A924 UB)      Ganymed
# 4    2001221          2001221    1221 Amor (1932 EA1)         Amor
# ..       ...              ...                     ...          ...
# 395  2096631          2096631       96631 (1999 FP59)          NaN
# 396  2096744          2096744        96744 (1999 OW3)          NaN
# 397  2097725          2097725      97725 (2000 GB147)          NaN
# 398  2098943          2098943       98943 (2001 CC21)          NaN
# 399  2099248          2099248       99248 (2001 KY66)          NaN
#
#     designation                                   nasa_jpl_url  \
# 0           433  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433
# 1           719  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719
# 2           887  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887
# 3          1036  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036
# 4          1221  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221
# ..          ...                                            ...
# 395       96631  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2096631
# 396       96744  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2096744
# 397       97725  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2097725
# 398       98943  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2098943
# 399       99248  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2099248
#
#      absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# 0                   10.43                              False
# 1                   15.51                              False
# 2                   13.87                              False
# 3                    9.25                              False
# 4                   17.39                              False
# ..                    ...                                ...
# 395                 18.10                              False
# 396                 14.82                              False
# 397                 18.72                              False
# 398                 18.41                              False
# 399                 16.53                               True
#
#                                    close_approach_data  is_sentry_object  ...  \
# 0    [{'close_approach_date': '1900-12-27', 'close_...             False  ...
# 1    [{'close_approach_date': '1909-08-21', 'close_...             False  ...
# 2    [{'close_approach_date': '1910-01-04', 'close_...             False  ...
# 3    [{'close_approach_date': '1910-02-25', 'close_...             False  ...
# 4    [{'close_approach_date': '1900-03-08', 'close_...             False  ...
# ..                                                 ...               ...  ...
# 395  [{'close_approach_date': '1904-08-24', 'close_...             False  ...
# 396  [{'close_approach_date': '1905-02-12', 'close_...             False  ...
# 397  [{'close_approach_date': '1911-02-20', 'close_...             False  ...
# 398  [{'close_approach_date': '1901-09-13', 'close_...             False  ...
# 399  [{'close_approach_date': '1917-07-18', 'close_...             False  ...
#
#     orbital_data.perihelion_distance  orbital_data.perihelion_argument  \
# 0                  1.133475820116491                 178.8971619902451
# 1                  1.194898892415675                 156.2275765643465
# 2                  1.062256387810841                 350.4932417946612
# 3                  1.244627432512162                 132.4281002671606
# 4                   1.08246658685257                 26.64392069638918
# ..                               ...                               ...
# 395                1.258143920287888                 303.7922621314381
# 396                .4604665148603528                 35.68888503160206
# 397                 1.24183060269858                 212.2737020563707
# 398                .8061337690558241                 179.4034269422497
# 399                .9187481399027259                 61.53095502278121
#
#      orbital_data.aphelion_distance  orbital_data.perihelion_time  \
# 0                  1.78307038061344          2459802.569605474861
# 1                 4.080111812929026          2459956.011943464095
# 2                 3.884059710445925          2459258.734847818714
# 3                 4.087071305845932          2458979.339225097543
# 4                 2.754995802947215          2459867.343755315685
# ..                              ...                           ...
# 395               2.139969904155277          2459588.048473050720
# 396               3.723088203232457          2460026.720256129510
# 397               2.354689434779702          2459603.683198941667
# 398               1.258452529165651          2459701.715980853057
# 399               2.813745130065296          2459669.558399245175
#
#      orbital_data.mean_anomaly  orbital_data.mean_motion  \
# 0            246.9041236220357         .5596877180622503
# 1            278.1971857577304         .2300986387269753
# 2            86.60720939790032         .2534114693822276
# 3            140.6548420252212         .2264387059007529
# 4            261.0445055510584         .3708368379536327
# ..                         ...                       ...
# 395           5.54133998971828         .4450329676263949
# 396          221.1438969828482         .3257848518934763
# 397          358.6989645721997         .4087194836521674
# 398          264.8850915351618         .9397222421123731
# 399          333.3027194877977         .3865899123641757
#
#      orbital_data.equinox  orbital_data.orbit_class.orbit_class_type  \
# 0                   J2000                                        AMO
# 1                   J2000                                        AMO
# 2                   J2000                                        AMO
# 3                   J2000                                        AMO
# 4                   J2000                                        AMO
# ..                    ...                                        ...
# 395                 J2000                                        AMO
# 396                 J2000                                        APO
# 397                 J2000                                        AMO
# 398                 J2000                                        APO
# 399                 J2000                                        APO
#
#       orbital_data.orbit_class.orbit_class_description  \
# 0    Near-Earth asteroid orbits similar to that of ...
# 1    Near-Earth asteroid orbits similar to that of ...
# 2    Near-Earth asteroid orbits similar to that of ...
# 3    Near-Earth asteroid orbits similar to that of ...
# 4    Near-Earth asteroid orbits similar to that of ...
# ..                                                 ...
# 395  Near-Earth asteroid orbits similar to that of ...
# 396  Near-Earth asteroid orbits which cross the Ear...
# 397  Near-Earth asteroid orbits similar to that of ...
# 398  Near-Earth asteroid orbits which cross the Ear...
# 399  Near-Earth asteroid orbits which cross the Ear...
#
#             orbital_data.orbit_class.orbit_class_range
# 0                   1.017 AU < q (perihelion) < 1.3 AU
# 1                   1.017 AU < q (perihelion) < 1.3 AU
# 2                   1.017 AU < q (perihelion) < 1.3 AU
# 3                   1.017 AU < q (perihelion) < 1.3 AU
# 4                   1.017 AU < q (perihelion) < 1.3 AU
# ..                                                 ...
# 395                 1.017 AU < q (perihelion) < 1.3 AU
# 396  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 397                 1.017 AU < q (perihelion) < 1.3 AU
# 398  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 399  a (semi-major axis) > 1.0 AU; q (perihelion) <...
#
# [400 rows x 44 columns]

# %% [markdown]
# Comprobemos la cantidad de objetos en el dataframe final, 10 páginas con 20 objetos cada una:

# %%
df_1.shape
# Out:
# (400, 44)

# %% [markdown]
# Guarda tu dataframe en el archivo `objetos_tierra_nasa.csv`:

# %%
df_1.to_csv("objetos_tierra_nasa.csv")

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reto 6: Automatizando peticiones
#
# ### 1. Objetivos:
#     - Automatizar la petición de datos a la API de la NASA por fechas.
#
# ---
#
# ### 2. Desarrollo:

# %%
from datetime import datetime

# %%
url = 'https://api.nasa.gov/neo/rest/v1/neo/browse/'
api_key ='y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW'

start_date = '1995-01-01'
end_date = '1995-02-28' 

parametros = {
    'api_key': api_key,
    '': start_date,
    '': end_date
}

# %% [markdown]
# ### a) Automatizando peticiones
#
# En el primer Reto realizaste una petición a la API de la NASA para pedir 5 datos de la hoja #100. Ahora, vamos a automatizar el proceso de realizar peticiones a la API para obtener una cantidad bastante mayor de datos.
#
# Vamos a obtener ahora los datos por fechas, así que tendrás que ir a la página de la [api de la NASA](https://api.nasa.gov/), para revisar cómo es posible realizar peticiones por fecha. Queremos obtener los **dos primeros meses (Enero y Febrero) del año 1995**. Observa que la API sólo permite peticiones por fecha en rangos de 7 días.
#
# Tu reto tiene los siguientes pasos:
#
# 1. Revisa la documentación de la API de la NASA para entender cómo realizar peticiones por fecha.
# 2. Realiza una primera petición de prueba para entender el formato de los datos que obtienes de regreso (cómo extraemos los datos que necesitamos y qué estructura tienen).
# 2. Escribe el código necesario para automatizar las peticiones a la API y obtener los meses de Enero y Febrero del año 1995.
# 3. Almacena los datos de cada petición y luego usa esos datos para crear `DataFrames`.
# 4. Concatena verticalmente tus `DataFrames` para obtener un `DataFrame` final que contenga todos los datos de tus peticiones. Cada fila tiene que corresponder a un objeto espacial.
# 5. Guarda tu `DataFrame` con el nombre de `near_earth_objects-january_february_1995-raw.csv`.
#
# > **Nota**: En este momento no te preocupes por explorar o limpiar tu dataset. Eso lo haremos en la siguiente sesión. Lo que sí tienes que asegurarte es de normalizar tus datos antes de convertirlos en `DataFrame`.
#
# ¡Mucha suerte!

# %%
def traer_datos_neo(url, parametros):
    """ Obtiene los datos de los obejetos cercanos a la tierra, de acuerdo a la url y los parámetros dados"""
    resultados = requests.get(url, params = parametros)
    if resultados.status_code == 200:
        datos = resultados.json() # regresa un diccionario
        objetos = datos["near_earth_objects"] # se obtienen 20 objetos por página
        return objetos 
    else:
        print("Error en la petición de requests")
        return None

# %%
datos = traer_datos_neo(url, parametros)
# Out:
# [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2099799?api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW'},
#   'id': '2099799',
#   'neo_reference_id': '2099799',
#   'name': '99799 (2002 LJ3)',
#   'designation': '99799',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2099799',
#   'absolute_magnitude_h': 18.36,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.5656593584,
#     'estimated_diameter_max': 1.2648527775},
#    'meters': {'estimated_diameter_min': 565.6593584222,
#     'estimated_diameter_max': 1264.852777541},
#    'miles': {'estimated_diameter_min': 0.3514843212,
#     'estimated_diameter_max': 0.7859428352},
#    'feet': {'estimated_diameter_min': 1855.8378494859,
#     'estimated_diameter_max': 4149.7795866675}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '1912-08-21',
#     'close_approach_date_full': '1912-Aug-21 09:07',
#     'epoch_date_close_approach': -1810219980000,
#     'relative_velocity': {'kilometers_per_second': '11.8335109975',
#      'kilometers_per_hour': '42600.6395911652',
#      'miles_per_hour': '26470.3807504104'},
#     'miss_distance': {'astronomical': '0.3068349013',
#      'lunar': '119.3587766057',
#      'kilometers': '45901847.676140231',
#      'miles': '28522085.5592719478'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1912-12-07',
#     'close_approach_date_full': '1912-Dec-07 16:06',
#     'epoch_date_close_approach': -1800863640000,
#     'relative_velocity': {'kilometers_per_second': '4.056443861',
#      'kilometers_per_hour': '14603.1978994542',
#      'miles_per_hour': '9073.8592725803'},
#     'miss_distance': {'astronomical': '0.3373442864',
#      'lunar': '131.2269274096',
#      'kilometers': '50465986.702109968',
#      'miles': '31358110.0418068384'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1919-09-07',
#     'close_approach_date_full': '1919-Sep-07 16:53',
#     'epoch_date_close_approach': -1587884820000,
#     'relative_velocity': {'kilometers_per_second': '3.7726451035',
#      'kilometers_per_hour': '13581.5223725878',
#      'miles_per_hour': '8439.0298320116'},
#     'miss_distance': {'astronomical': '0.1926624297',
#      'lunar': '74.9456851533',
#      'kilometers': '28821889.112144739',
#      'miles': '17909091.4386818382'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1935-08-15',
#     'close_approach_date_full': '1935-Aug-15 19:23',
#     'epoch_date_close_approach': -1084941420000,
#     'relative_velocity': {'kilometers_per_second': '15.5472718989',
#      'kilometers_per_hour': '55970.1788359345',
#      'miles_per_hour': '34777.6925105839'},
#     'miss_distance': {'astronomical': '0.4345471237',
#      'lunar': '169.0388311193',
#      'kilometers': '65007324.120146519',
#      'miles': '40393678.1285152022'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1935-12-24',
#     'close_approach_date_full': '1935-Dec-24 04:35',
#     'epoch_date_close_approach': -1073676300000,
#     'relative_velocity': {'kilometers_per_second': '5.7494167377',
#      'kilometers_per_hour': '20697.900255855',
#      'miles_per_hour': '12860.870300645'},
#     'miss_distance': {'astronomical': '0.4141988009',
#      'lunar': '161.1233335501',
#      'kilometers': '61963258.371194083',
#      'miles': '38502183.3818930254'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1942-09-05',
#     'close_approach_date_full': '1942-Sep-05 05:11',
#     'epoch_date_close_approach': -862253340000,
#     'relative_velocity': {'kilometers_per_second': '4.3930649481',
#      'kilometers_per_hour': '15815.0338133217',
#      'miles_per_hour': '9826.8469825054'},
#     'miss_distance': {'astronomical': '0.1242873154',
#      'lunar': '48.3477656906',
#      'kilometers': '18593117.651858198',
#      'miles': '11553227.5785832124'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1949-07-09',
#     'close_approach_date_full': '1949-Jul-09 06:52',
#     'epoch_date_close_approach': -646333680000,
#     'relative_velocity': {'kilometers_per_second': '5.3580076261',
#      'kilometers_per_hour': '19288.8274541211',
#      'miles_per_hour': '11985.3272589232'},
#     'miss_distance': {'astronomical': '0.4404061525',
#      'lunar': '171.3179933225',
#      'kilometers': '65883822.348895175',
#      'miles': '40938308.872996415'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1949-11-09',
#     'close_approach_date_full': '1949-Nov-09 08:24',
#     'epoch_date_close_approach': -635700960000,
#     'relative_velocity': {'kilometers_per_second': '16.0958235887',
#      'kilometers_per_hour': '57944.9649191825',
#      'miles_per_hour': '36004.7477854776'},
#     'miss_distance': {'astronomical': '0.4992424948',
#      'lunar': '194.2053304772',
#      'kilometers': '74685613.835566076',
#      'miles': '46407488.4935848088'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1959-01-01',
#     'close_approach_date_full': '1959-Jan-01 21:06',
#     'epoch_date_close_approach': -347079240000,
#     'relative_velocity': {'kilometers_per_second': '6.6442065618',
#      'kilometers_per_hour': '23919.1436224057',
#      'miles_per_hour': '14862.4256580443'},
#     'miss_distance': {'astronomical': '0.4651661392',
#      'lunar': '180.9496281488',
#      'kilometers': '69587863.620443504',
#      'miles': '43239893.3932441952'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1965-09-01',
#     'close_approach_date_full': '1965-Sep-01 09:34',
#     'epoch_date_close_approach': -136736760000,
#     'relative_velocity': {'kilometers_per_second': '6.1010173333',
#      'kilometers_per_hour': '21963.6623999114',
#      'miles_per_hour': '13647.3656728783'},
#     'miss_distance': {'astronomical': '0.1326808129',
#      'lunar': '51.6128362181',
#      'kilometers': '19848766.999708523',
#      'miles': '12333451.9038546974'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1972-07-22',
#     'close_approach_date_full': '1972-Jul-22 01:06',
#     'epoch_date_close_approach': 80615160000,
#     'relative_velocity': {'kilometers_per_second': '4.5308384472',
#      'kilometers_per_hour': '16311.0184098925',
#      'miles_per_hour': '10135.0325225246'},
#     'miss_distance': {'astronomical': '0.3719275118',
#      'lunar': '144.6798020902',
#      'kilometers': '55639563.559679866',
#      'miles': '34572821.6329435108'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1972-11-02',
#     'close_approach_date_full': '1972-Nov-02 17:51',
#     'epoch_date_close_approach': 89574660000,
#     'relative_velocity': {'kilometers_per_second': '12.7819601908',
#      'kilometers_per_hour': '46015.056686795',
#      'miles_per_hour': '28591.9667507477'},
#     'miss_distance': {'astronomical': '0.3952930766',
#      'lunar': '153.7690067974',
#      'kilometers': '59135002.285106842',
#      'miles': '36744786.5415727396'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1985-09-16',
#     'close_approach_date_full': '1985-Sep-16 04:14',
#     'epoch_date_close_approach': 495692040000,
#     'relative_velocity': {'kilometers_per_second': '4.9663119581',
#      'kilometers_per_hour': '17878.7230492052',
#      'miles_per_hour': '11109.143219102'},
#     'miss_distance': {'astronomical': '0.0584122325',
#      'lunar': '22.7223584425',
#      'kilometers': '8738345.563944775',
#      'miles': '5429756.152296895'},
#     'orbiting_body': 'Mars'},
#    {'close_approach_date': '1988-08-25',
#     'close_approach_date_full': '1988-Aug-25 07:54',
#     'epoch_date_close_approach': 588498840000,
#     'relative_velocity': {'kilometers_per_second': '9.915700497',
#      'kilometers_per_hour': '35696.5217891289',
#      'miles_per_hour': '22180.4304416951'},
#     'miss_distance': {'astronomical': '0.2417639083',
#      'lunar': '94.0461603287',
#      'kilometers': '36167365.724555321',
#      'miles': '22473358.9577365898'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1988-11-25',
#     'close_approach_date_full': '1988-Nov-25 01:38',
#     'epoch_date_close_approach': 596425080000,
#     'relative_velocity': {'kilometers_per_second': '2.5949167063',
#      'kilometers_per_hour': '9341.7001427884',
#      'miles_per_hour': '5804.5691803898'},
#     'miss_distance': {'astronomical': '0.2914423441',
#      'lunar': '113.3710718549',
#      'kilometers': '43599153.905167067',
#      'miles': '27091257.9983448446'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1995-08-22',
#     'close_approach_date_full': '1995-Aug-22 21:59',
#     'epoch_date_close_approach': 809128740000,
#     'relative_velocity': {'kilometers_per_second': '3.6316296128',
#      'kilometers_per_hour': '13073.8666061024',
#      'miles_per_hour': '8123.5922808862'},
#     'miss_distance': {'astronomical': '0.2472565536',
#      'lunar': '96.1827993504',
#      'kilometers': '36989053.762100832',
#      'miles': '22983932.2286702016'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1995-10-20',
#     'close_approach_date_full': '1995-Oct-20 01:25',
#     'epoch_date_close_approach': 814152300000,
#     'relative_velocity': {'kilometers_per_second': '7.432552795',
#      'kilometers_per_hour': '26757.1900621213',
#      'miles_per_hour': '16625.8773472109'},
#     'miss_distance': {'astronomical': '0.2457573335',
#      'lunar': '95.5996027315',
#      'kilometers': '36764773.628479645',
#      'miles': '22844571.015903301'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2011-08-18',
#     'close_approach_date_full': '2011-Aug-18 00:39',
#     'epoch_date_close_approach': 1313627940000,
#     'relative_velocity': {'kilometers_per_second': '14.6490607288',
#      'kilometers_per_hour': '52736.6186237203',
#      'miles_per_hour': '32768.4839442778'},
#     'miss_distance': {'astronomical': '0.4028845089',
#      'lunar': '156.7220739621',
#      'kilometers': '60270664.387436043',
#      'miles': '37450454.2497136734'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2011-12-21',
#     'close_approach_date_full': '2011-Dec-21 18:24',
#     'epoch_date_close_approach': 1324491840000,
#     'relative_velocity': {'kilometers_per_second': '5.4122552273',
#      'kilometers_per_hour': '19484.1188182928',
#      'miles_per_hour': '12106.6737179553'},
#     'miss_distance': {'astronomical': '0.3961580549',
#      'lunar': '154.1054833561',
#      'kilometers': '59264401.196383063',
#      'miles': '36825191.2966217494'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2018-09-06',
#     'close_approach_date_full': '2018-Sep-06 18:53',
#     'epoch_date_close_approach': 1536259980000,
#     'relative_velocity': {'kilometers_per_second': '4.0807994888',
#      'kilometers_per_hour': '14690.8781595384',
#      'miles_per_hour': '9128.3403764088'},
#     'miss_distance': {'astronomical': '0.1321576386',
#      'lunar': '51.4093214154',
#      'kilometers': '19770501.238789782',
#      'miles': '12284819.8151197116'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2025-07-08',
#     'close_approach_date_full': '2025-Jul-08 19:08',
#     'epoch_date_close_approach': 1752001680000,
#     'relative_velocity': {'kilometers_per_second': '5.4614657228',
#      'kilometers_per_hour': '19661.2766019394',
#      'miles_per_hour': '12216.7526752439'},
#     'miss_distance': {'astronomical': '0.4466571183',
#      'lunar': '173.7496190187',
#      'kilometers': '66818953.518018021',
#      'miles': '41519372.4372138498'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2035-01-02',
#     'close_approach_date_full': '2035-Jan-02 16:43',
#     'epoch_date_close_approach': 2051368980000,
#     'relative_velocity': {'kilometers_per_second': '6.6569644092',
#      'kilometers_per_hour': '23965.0718732426',
#      'miles_per_hour': '14890.9636870157'},
#     'miss_distance': {'astronomical': '0.4653695768',
#      'lunar': '181.0287653752',
#      'kilometers': '69618297.452081416',
#      'miles': '43258804.0993229008'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2041-09-01',
#     'close_approach_date_full': '2041-Sep-01 16:06',
#     'epoch_date_close_approach': 2261664360000,
#     'relative_velocity': {'kilometers_per_second': '6.2880356389',
#      'kilometers_per_hour': '22636.9282999387',
#      'miles_per_hour': '14065.7069205924'},
#     'miss_distance': {'astronomical': '0.1369936187',
#      'lunar': '53.2905176743',
#      'kilometers': '20493953.561112169',
#      'miles': '12734352.2431151722'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2044-01-08',
#     'close_approach_date_full': '2044-Jan-08 18:15',
#     'epoch_date_close_approach': 2335889700000,
#     'relative_velocity': {'kilometers_per_second': '5.9871237654',
#      'kilometers_per_hour': '21553.6455554135',
#      'miles_per_hour': '13392.5971508068'},
#     'miss_distance': {'astronomical': '0.0404814434',
#      'lunar': '15.7472814826',
#      'kilometers': '6055937.707165558',
#      'miles': '3762985.1992903804'},
#     'orbiting_body': 'Mars'},
#    {'close_approach_date': '2048-07-24',
#     'close_approach_date_full': '2048-Jul-24 05:12',
#     'epoch_date_close_approach': 2479180320000,
#     'relative_velocity': {'kilometers_per_second': '4.4521417089',
#      'kilometers_per_hour': '16027.7101519341',
#      'miles_per_hour': '9958.9957885726'},
#     'miss_distance': {'astronomical': '0.3644265907',
#      'lunar': '141.7619437823',
#      'kilometers': '54517441.740081809',
#      'miles': '33875567.4663506042'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2048-11-03',
#     'close_approach_date_full': '2048-Nov-03 08:16',
#     'epoch_date_close_approach': 2488004160000,
#     'relative_velocity': {'kilometers_per_second': '12.4864264427',
#      'kilometers_per_hour': '44951.1351938176',
#      'miles_per_hour': '27930.8873097362'},
#     'miss_distance': {'astronomical': '0.3845834851',
#      'lunar': '149.6029757039',
#      'kilometers': '57532870.208136737',
#      'miles': '35749267.8317594906'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2064-08-25',
#     'close_approach_date_full': '2064-Aug-25 14:03',
#     'epoch_date_close_approach': 2986898580000,
#     'relative_velocity': {'kilometers_per_second': '10.190035876',
#      'kilometers_per_hour': '36684.1291536112',
#      'miles_per_hour': '22794.0912510313'},
#     'miss_distance': {'astronomical': '0.251311675',
#      'lunar': '97.760241575',
#      'kilometers': '37595691.28613225',
#      'miles': '23360879.30683505'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2064-11-28',
#     'close_approach_date_full': '2064-Nov-28 16:38',
#     'epoch_date_close_approach': 2995115880000,
#     'relative_velocity': {'kilometers_per_second': '2.9410467722',
#      'kilometers_per_hour': '10587.7683800289',
#      'miles_per_hour': '6578.8275248019'},
#     'miss_distance': {'astronomical': '0.2978459115',
#      'lunar': '115.8620595735',
#      'kilometers': '44557113.948608505',
#      'miles': '27686506.767287169'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2071-08-24',
#     'close_approach_date_full': '2071-Aug-24 05:54',
#     'epoch_date_close_approach': 3207621240000,
#     'relative_velocity': {'kilometers_per_second': '3.5940670815',
#      'kilometers_per_hour': '12938.6414934446',
#      'miles_per_hour': '8039.5686546351'},
#     'miss_distance': {'astronomical': '0.2442981535',
#      'lunar': '95.0319817115',
#      'kilometers': '36546483.408533045',
#      'miles': '22708931.762904221'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2071-10-21',
#     'close_approach_date_full': '2071-Oct-21 06:10',
#     'epoch_date_close_approach': 3212633400000,
#     'relative_velocity': {'kilometers_per_second': '7.3597472827',
#      'kilometers_per_hour': '26495.0902175878',
#      'miles_per_hour': '16463.0186965895'},
#     'miss_distance': {'astronomical': '0.2423464327',
#      'lunar': '94.2727623203',
#      'kilometers': '36254510.134018349',
#      'miles': '22527507.9828532562'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2087-08-19',
#     'close_approach_date_full': '2087-Aug-19 05:48',
#     'epoch_date_close_approach': 3712110480000,
#     'relative_velocity': {'kilometers_per_second': '14.3835773465',
#      'kilometers_per_hour': '51780.8784475433',
#      'miles_per_hour': '32174.6241664749'},
#     'miss_distance': {'astronomical': '0.3939889308',
#      'lunar': '153.2616940812',
#      'kilometers': '58939904.851257396',
#      'miles': '36623558.6175922248'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2087-12-21',
#     'close_approach_date_full': '2087-Dec-21 11:53',
#     'epoch_date_close_approach': 3722845980000,
#     'relative_velocity': {'kilometers_per_second': '5.3108320636',
#      'kilometers_per_hour': '19118.9954291352',
#      'miles_per_hour': '11879.8002431757'},
#     'miss_distance': {'astronomical': '0.3904914867',
#      'lunar': '151.9011883263',
#      'kilometers': '58416694.663453329',
#      'miles': '36298450.8823367802'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2094-09-08',
#     'close_approach_date_full': '2094-Sep-08 04:37',
#     'epoch_date_close_approach': 3934759020000,
#     'relative_velocity': {'kilometers_per_second': '3.8692080724',
#      'kilometers_per_hour': '13929.1490606188',
#      'miles_per_hour': '8655.0315371384'},
#     'miss_distance': {'astronomical': '0.1403494931',
#      'lunar': '54.5959528159',
#      'kilometers': '20995985.223339697',
#      'miles': '13046300.2528019386'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2101-07-07',
#     'close_approach_date_full': '2101-Jul-07 21:23',
#     'epoch_date_close_approach': 4150214580000,
#     'relative_velocity': {'kilometers_per_second': '5.6774538109',
#      'kilometers_per_hour': '20438.8337191082',
#      'miles_per_hour': '12699.8964295203'},
#     'miss_distance': {'astronomical': '0.4616504268',
#      'lunar': '179.5820160252',
#      'kilometers': '69061920.533870916',
#      'miles': '42913087.5134380008'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2110-08-15',
#     'close_approach_date_full': '2110-Aug-15 09:36',
#     'epoch_date_close_approach': 4437538560000,
#     'relative_velocity': {'kilometers_per_second': '17.2122988464',
#      'kilometers_per_hour': '61964.275847134',
#      'miles_per_hour': '38502.1912895705'},
#     'miss_distance': {'astronomical': '0.4933868701',
#      'lunar': '191.9274924689',
#      'kilometers': '73809624.852926687',
#      'miles': '45863174.1799628006'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2111-01-01',
#     'close_approach_date_full': '2111-Jan-01 04:25',
#     'epoch_date_close_approach': 4449529500000,
#     'relative_velocity': {'kilometers_per_second': '6.3179949499',
#      'kilometers_per_hour': '22744.7818196565',
#      'miles_per_hour': '14132.7229034415'},
#     'miss_distance': {'astronomical': '0.4457431094',
#      'lunar': '173.3940695566',
#      'kilometers': '66682219.733416978',
#      'miles': '41434410.0032231764'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2117-09-05',
#     'close_approach_date_full': '2117-Sep-05 15:40',
#     'epoch_date_close_approach': 4660299600000,
#     'relative_velocity': {'kilometers_per_second': '5.1970990377',
#      'kilometers_per_hour': '18709.5565357788',
#      'miles_per_hour': '11625.3908374677'},
#     'miss_distance': {'astronomical': '0.1229716348',
#      'lunar': '47.8359659372',
#      'kilometers': '18396294.636497876',
#      'miles': '11430927.4279716488'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2124-07-17',
#     'close_approach_date_full': '2124-Jul-17 17:47',
#     'epoch_date_close_approach': 4876912020000,
#     'relative_velocity': {'kilometers_per_second': '4.9805945795',
#      'kilometers_per_hour': '17930.1404860502',
#      'miles_per_hour': '11141.0920147905'},
#     'miss_distance': {'astronomical': '0.4058382175',
#      'lunar': '157.8710666075',
#      'kilometers': '60712532.902596725',
#      'miles': '37725018.613315805'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2124-11-09',
#     'close_approach_date_full': '2124-Nov-09 14:22',
#     'epoch_date_close_approach': 4886835720000,
#     'relative_velocity': {'kilometers_per_second': '14.486596891',
#      'kilometers_per_hour': '52151.7488076832',
#      'miles_per_hour': '32405.0685855296'},
#     'miss_distance': {'astronomical': '0.4443106606',
#      'lunar': '172.8368469734',
#      'kilometers': '66467928.444052922',
#      'miles': '41301255.5704654436'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2132-06-01',
#     'close_approach_date_full': '2132-Jun-01 16:51',
#     'epoch_date_close_approach': 5125395060000,
#     'relative_velocity': {'kilometers_per_second': '5.0718566375',
#      'kilometers_per_hour': '18258.6838950596',
#      'miles_per_hour': '11345.2361124608'},
#     'miss_distance': {'astronomical': '0.0538724658',
#      'lunar': '20.9563891962',
#      'kilometers': '8059206.135327846',
#      'miles': '5007758.4796464348'},
#     'orbiting_body': 'Mars'},
#    {'close_approach_date': '2134-01-09',
#     'close_approach_date_full': '2134-Jan-09 17:31',
#     'epoch_date_close_approach': 5176114260000,
#     'relative_velocity': {'kilometers_per_second': '7.1704287882',
#      'kilometers_per_hour': '25813.54363742',
#      'miles_per_hour': '16039.5321562624'},
#     'miss_distance': {'astronomical': '0.4985883714',
#      'lunar': '193.9508764746',
#      'kilometers': '74587758.368208918',
#      'miles': '46346683.9257143484'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2140-08-30',
#     'close_approach_date_full': '2140-Aug-30 23:00',
#     'epoch_date_close_approach': 5385654000000,
#     'relative_velocity': {'kilometers_per_second': '8.1386611263',
#      'kilometers_per_hour': '29299.1800546709',
#      'miles_per_hour': '18205.3710734148'},
#     'miss_distance': {'astronomical': '0.1865827739',
#      'lunar': '72.5806990471',
#      'kilometers': '27912385.554131593',
#      'miles': '17343952.1335902634'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2147-08-08',
#     'close_approach_date_full': '2147-Aug-08 19:13',
#     'epoch_date_close_approach': 5604577980000,
#     'relative_velocity': {'kilometers_per_second': '3.860610272',
#      'kilometers_per_hour': '13898.1969791193',
#      'miles_per_hour': '8635.7991173866'},
#     'miss_distance': {'astronomical': '0.3048525243',
#      'lunar': '118.5876319527',
#      'kilometers': '45605288.299403241',
#      'miles': '28337812.1074410858'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2147-11-01',
#     'close_approach_date_full': '2147-Nov-01 08:53',
#     'epoch_date_close_approach': 5611884780000,
#     'relative_velocity': {'kilometers_per_second': '10.00614074',
#      'kilometers_per_hour': '36022.1066640727',
#      'miles_per_hour': '22382.7362213512'},
#     'miss_distance': {'astronomical': '0.3068170499',
#      'lunar': '119.3518324111',
#      'kilometers': '45899177.144723713',
#      'miles': '28520426.1679967194'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2163-08-23',
#     'close_approach_date_full': '2163-Aug-23 17:09',
#     'epoch_date_close_approach': 6110788140000,
#     'relative_velocity': {'kilometers_per_second': '12.8563921033',
#      'kilometers_per_hour': '46283.0115718818',
#      'miles_per_hour': '28758.4634958729'},
#     'miss_distance': {'astronomical': '0.3422336783',
#      'lunar': '133.1289008587',
#      'kilometers': '51197429.315945221',
#      'miles': '31812607.4067212098'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2163-12-16',
#     'close_approach_date_full': '2163-Dec-16 23:33',
#     'epoch_date_close_approach': 6120747180000,
#     'relative_velocity': {'kilometers_per_second': '4.641847169',
#      'kilometers_per_hour': '16710.6498085361',
#      'miles_per_hour': '10383.3479324207'},
#     'miss_distance': {'astronomical': '0.3583820226',
#      'lunar': '139.4106067914',
#      'kilometers': '53613187.227251862',
#      'miles': '33313689.7666932156'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2170-09-11',
#     'close_approach_date_full': '2170-Sep-11 11:36',
#     'epoch_date_close_approach': 6333334560000,
#     'relative_velocity': {'kilometers_per_second': '3.5895119646',
#      'kilometers_per_hour': '12922.2430724916',
#      'miles_per_hour': '8029.3793135713'},
#     'miss_distance': {'astronomical': '0.1671019598',
#      'lunar': '65.0026623622',
#      'kilometers': '24998097.258905626',
#      'miles': '15533097.3573885988'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2177-07-05',
#     'close_approach_date_full': '2177-Jul-05 04:27',
#     'epoch_date_close_approach': 6548358420000,
#     'relative_velocity': {'kilometers_per_second': '5.9570118546',
#      'kilometers_per_hour': '21445.2426766816',
#      'miles_per_hour': '13325.2398176303'},
#     'miss_distance': {'astronomical': '0.4809754271',
#      'lunar': '187.0994411419',
#      'kilometers': '71952899.416500277',
#      'miles': '44709458.4922747426'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2186-08-17',
#     'close_approach_date_full': '2186-Aug-17 07:24',
#     'epoch_date_close_approach': 6836081040000,
#     'relative_velocity': {'kilometers_per_second': '16.5409855281',
#      'kilometers_per_hour': '59547.5479011074',
#      'miles_per_hour': '37000.5305277742'},
#     'miss_distance': {'astronomical': '0.4705198887',
#      'lunar': '183.0322367043',
#      'kilometers': '70388773.142157069',
#      'miles': '43737555.4931387922'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2186-12-30',
#     'close_approach_date_full': '2186-Dec-30 20:29',
#     'epoch_date_close_approach': 6847792140000,
#     'relative_velocity': {'kilometers_per_second': '6.1023363039',
#      'kilometers_per_hour': '21968.4106940775',
#      'miles_per_hour': '13650.3160782172'},
#     'miss_distance': {'astronomical': '0.4330854793',
#      'lunar': '168.4702514477',
#      'kilometers': '64788665.231209091',
#      'miles': '40257809.7952278158'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2190-09-24',
#     'close_approach_date_full': '2190-Sep-24 22:02',
#     'epoch_date_close_approach': 6965647320000,
#     'relative_velocity': {'kilometers_per_second': '6.1533740504',
#      'kilometers_per_hour': '22152.1465813058',
#      'miles_per_hour': '13764.4824132564'},
#     'miss_distance': {'astronomical': '0.052702388',
#      'lunar': '20.501228932',
#      'kilometers': '7884164.98871356',
#      'miles': '4898992.954664728'},
#     'orbiting_body': 'Mars'},
#    {'close_approach_date': '2193-09-07',
#     'close_approach_date_full': '2193-Sep-07 04:53',
#     'epoch_date_close_approach': 7058811180000,
#     'relative_velocity': {'kilometers_per_second': '4.8323514981',
#      'kilometers_per_hour': '17396.4653933123',
#      'miles_per_hour': '10809.4870661945'},
#     'miss_distance': {'astronomical': '0.1230119839',
#      'lunar': '47.8516617371',
#      'kilometers': '18402330.775914293',
#      'miles': '11434678.1110835234'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2200-07-16',
#     'close_approach_date_full': '2200-Jul-16 23:48',
#     'epoch_date_close_approach': 7275138480000,
#     'relative_velocity': {'kilometers_per_second': '5.1641954218',
#      'kilometers_per_hour': '18591.1035184005',
#      'miles_per_hour': '11551.788738975'},
#     'miss_distance': {'astronomical': '0.4187580657',
#      'lunar': '162.8968875573',
#      'kilometers': '62645314.674040059',
#      'miles': '38925993.5161444542'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2200-11-12',
#     'close_approach_date_full': '2200-Nov-12 23:46',
#     'epoch_date_close_approach': 7285419960000,
#     'relative_velocity': {'kilometers_per_second': '15.1652212757',
#      'kilometers_per_hour': '54594.7965924098',
#      'miles_per_hour': '33923.0834715449'},
#     'miss_distance': {'astronomical': '0.4641550681',
#      'lunar': '180.5563214909',
#      'kilometers': '69436609.537464947',
#      'miles': '43145908.4642203886'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '174',
#    'orbit_determination_date': '2021-12-24 04:52:13',
#    'first_observation_date': '1989-01-10',
#    'last_observation_date': '2021-03-18',
#    'data_arc_in_days': 11755,
#    'observations_used': 787,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.121487',
#    'jupiter_tisserand_invariant': '4.569',
#    'epoch_osculation': '2459600.5',
#    'eccentricity': '.2757691854498572',
#    'semi_major_axis': '1.46189214949269',
#    'inclination': '7.55778601877821',
#    'ascending_node_longitude': '122.3624772314261',
#    'orbital_period': '645.6117527768314',
#    'perihelion_distance': '1.05874734221155',
#    'perihelion_argument': '249.8871315625245',
#    'aphelion_distance': '1.865036956773831',
#    'perihelion_time': '2459690.576515417136',
#    'mean_anomaly': '309.7723741696225',
#    'mean_motion': '.5576106668622577',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2099907?api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW'},
#   'id': '2099907',
#   'neo_reference_id': '2099907',
#   'name': '99907 (1989 VA)',
#   'designation': '99907',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2099907',
#   'absolute_magnitude_h': 17.91,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.6959130436,
#     'estimated_diameter_max': 1.5561088719},
#    'meters': {'estimated_diameter_min': 695.9130435846,
#     'estimated_diameter_max': 1556.108871884},
#    'miles': {'estimated_diameter_min': 0.4324201838,
#     'estimated_diameter_max': 0.9669209258},
#    'feet': {'estimated_diameter_min': 2283.1793499141,
#     'estimated_diameter_max': 5105.3442312318}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '1900-10-23',
#     'close_approach_date_full': '1900-Oct-23 23:36',
#     'epoch_date_close_approach': -2183415840000,
#     'relative_velocity': {'kilometers_per_second': '22.4890226046',
#      'kilometers_per_hour': '80960.4813766511',
#      'miles_per_hour': '50305.6946642863'},
#     'miss_distance': {'astronomical': '0.2487051286',
#      'lunar': '96.7462950254',
#      'kilometers': '37205757.496636082',
#      'miles': '23118585.6853466516'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1902-11-21',
#     'close_approach_date_full': '1902-Nov-21 00:26',
#     'epoch_date_close_approach': -2117921640000,
#     'relative_velocity': {'kilometers_per_second': '17.574422645',
#      'kilometers_per_hour': '63267.921522063',
#      'miles_per_hour': '39312.2260146396'},
#     'miss_distance': {'astronomical': '0.1918746033',
#      'lunar': '74.6392206837',
#      'kilometers': '28704031.960774971',
#      'miles': '17835858.4006817598'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1905-10-24',
#     'close_approach_date_full': '1905-Oct-24 17:48',
#     'epoch_date_close_approach': -2025583920000,
#     'relative_velocity': {'kilometers_per_second': '19.3051251917',
#      'kilometers_per_hour': '69498.4506900415',
#      'miles_per_hour': '43183.634541265'},
#     'miss_distance': {'astronomical': '0.1766248827',
#      'lunar': '68.7070793703',
#      'kilometers': '26422706.240919849',
#      'miles': '16418308.3310339562'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1907-11-26',
#     'close_approach_date_full': '1907-Nov-26 03:30',
#     'epoch_date_close_approach': -1959712200000,
#     'relative_velocity': {'kilometers_per_second': '19.3429416259',
#      'kilometers_per_hour': '69634.5898530874',
#      'miles_per_hour': '43268.2261228809'},
#     'miss_distance': {'astronomical': '0.2258149463',
#      'lunar': '87.8420141107',
#      'kilometers': '33781434.980644381',
#      'miles': '20990810.3401632178'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1910-10-29',
#     'close_approach_date_full': '1910-Oct-29 11:56',
#     'epoch_date_close_approach': -1867406640000,
#     'relative_velocity': {'kilometers_per_second': '17.5682988904',
#      'kilometers_per_hour': '63245.8760053457',
#      'miles_per_hour': '39298.5277878772'},
#     'miss_distance': {'astronomical': '0.1562655097',
#      'lunar': '60.7872832733',
#      'kilometers': '23376987.405584339',
#      'miles': '14525786.4041643182'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1912-11-26',
#     'close_approach_date_full': '1912-Nov-26 00:43',
#     'epoch_date_close_approach': -1801869420000,
#     'relative_velocity': {'kilometers_per_second': '22.6789573136',
#      'kilometers_per_hour': '81644.2463288376',
#      'miles_per_hour': '50730.5596147158'},
#     'miss_distance': {'astronomical': '0.2992701817',
#      'lunar': '116.4161006813',
#      'kilometers': '44770181.736832979',
#      'miles': '27818900.9516899502'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1913-10-31',
#     'close_approach_date_full': '1913-Oct-31 15:47',
#     'epoch_date_close_approach': -1772525580000,
#     'relative_velocity': {'kilometers_per_second': '31.4374963096',
#      'kilometers_per_hour': '113174.9867144297',
#      'miles_per_hour': '70322.5354948633'},
#     'miss_distance': {'astronomical': '0.4787401912',
#      'lunar': '186.2299343768',
#      'kilometers': '71618512.886912744',
#      'miles': '44501680.3375901072'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1915-11-05',
#     'close_approach_date_full': '1915-Nov-05 21:42',
#     'epoch_date_close_approach': -1709000280000,
#     'relative_velocity': {'kilometers_per_second': '16.9893034345',
#      'kilometers_per_hour': '61161.4923641608',
#      'miles_per_hour': '38003.3728526087'},
#     'miss_distance': {'astronomical': '0.1668964718',
#      'lunar': '64.9227275302',
#      'kilometers': '24967356.691795066',
#      'miles': '15513996.0547252708'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1917-11-23',
#     'close_approach_date_full': '1917-Nov-23 11:32',
#     'epoch_date_close_approach': -1644323280000,
#     'relative_velocity': {'kilometers_per_second': '26.9941066951',
#      'kilometers_per_hour': '97178.7841024846',
#      'miles_per_hour': '60383.1172663466'},
#     'miss_distance': {'astronomical': '0.402679025',
#      'lunar': '156.642140725',
#      'kilometers': '60239924.43367675',
#      'miles': '37431353.32816915'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1918-10-27',
#     'close_approach_date_full': '1918-Oct-27 09:49',
#     'epoch_date_close_approach': -1615126260000,
#     'relative_velocity': {'kilometers_per_second': '26.7685671078',
#      'kilometers_per_hour': '96366.8415879781',
#      'miles_per_hour': '59878.6077633745'},
#     'miss_distance': {'astronomical': '0.3580909757',
#      'lunar': '139.2973895473',
#      'kilometers': '53569647.230941759',
#      'miles': '33286635.2675199142'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1920-11-12',
#     'close_approach_date_full': '1920-Nov-12 23:34',
#     'epoch_date_close_approach': -1550535960000,
#     'relative_velocity': {'kilometers_per_second': '16.988067864',
#      'kilometers_per_hour': '61157.0443105202',
#      'miles_per_hour': '38000.6090050563'},
#     'miss_distance': {'astronomical': '0.1791964077',
#      'lunar': '69.7074025953',
#      'kilometers': '26807400.903571599',
#      'miles': '16657346.5100581062'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1923-10-24',
#     'close_approach_date_full': '1923-Oct-24 22:50',
#     'epoch_date_close_approach': -1457572200000,
#     'relative_velocity': {'kilometers_per_second': '22.6871787048',
#      'kilometers_per_hour': '81673.8433374463',
#      'miles_per_hour': '50748.9500448705'},
#     'miss_distance': {'astronomical': '0.2536268399',
#      'lunar': '98.6608407211',
#      'kilometers': '37942035.023871013',
#      'miles': '23576087.3261374594'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1925-11-20',
#     'close_approach_date_full': '1925-Nov-20 10:03',
#     'epoch_date_close_approach': -1392127020000,
#     'relative_velocity': {'kilometers_per_second': '17.5043187969',
#      'kilometers_per_hour': '63015.5476688332',
#      'miles_per_hour': '39155.4107167814'},
#     'miss_distance': {'astronomical': '0.1911050882',
#      'lunar': '74.3398793098',
#      'kilometers': '28588914.140882134',
#      'miles': '17764327.5043320892'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1928-10-24',
#     'close_approach_date_full': '1928-Oct-24 08:35',
#     'epoch_date_close_approach': -1299770700000,
#     'relative_velocity': {'kilometers_per_second': '19.5762111283',
#      'kilometers_per_hour': '70474.3600619574',
#      'miles_per_hour': '43790.0266729424'},
#     'miss_distance': {'astronomical': '0.1814905708',
#      'lunar': '70.5998320412',
#      'kilometers': '27150602.816764196',
#      'miles': '16870602.2901140648'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1930-11-25',
#     'close_approach_date_full': '1930-Nov-25 14:34',
#     'epoch_date_close_approach': -1233912360000,
#     'relative_velocity': {'kilometers_per_second': '18.9890139204',
#      'kilometers_per_hour': '68360.4501132935',
#      'miles_per_hour': '42476.5252384517'},
#     'miss_distance': {'astronomical': '0.2194098047',
#      'lunar': '85.3504140283',
#      'kilometers': '32823239.440235989',
#      'miles': '20395415.2401910882'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1933-10-28',
#     'close_approach_date_full': '1933-Oct-28 03:38',
#     'epoch_date_close_approach': -1141676520000,
#     'relative_velocity': {'kilometers_per_second': '17.7945359432',
#      'kilometers_per_hour': '64060.3293956766',
#      'miles_per_hour': '39804.5974514414'},
#     'miss_distance': {'astronomical': '0.1565498869',
#      'lunar': '60.8979060041',
#      'kilometers': '23419529.628980903',
#      'miles': '14552220.9159983414'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1935-11-27',
#     'close_approach_date_full': '1935-Nov-27 04:55',
#     'epoch_date_close_approach': -1076007900000,
#     'relative_velocity': {'kilometers_per_second': '21.7261490015',
#      'kilometers_per_hour': '78214.1364052614',
#      'miles_per_hour': '48599.2227013692'},
#     'miss_distance': {'astronomical': '0.2778100081',
#      'lunar': '108.0680931509',
#      'kilometers': '41559785.476442747',
#      'miles': '25824053.2178020286'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1938-11-03',
#     'close_approach_date_full': '1938-Nov-03 07:45',
#     'epoch_date_close_approach': -983376900000,
#     'relative_velocity': {'kilometers_per_second': '17.0736639246',
#      'kilometers_per_hour': '61465.1901284545',
#      'miles_per_hour': '38192.0788328722'},
#     'miss_distance': {'astronomical': '0.1627961114',
#      'lunar': '63.3276873346',
#      'kilometers': '24353951.509722718',
#      'miles': '15132843.7488527884'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1940-11-24',
#     'close_approach_date_full': '1940-Nov-24 16:50',
#     'epoch_date_close_approach': -918371400000,
#     'relative_velocity': {'kilometers_per_second': '25.3838840431',
#      'kilometers_per_hour': '91381.9825549894',
#      'miles_per_hour': '56781.2102159044'},
#     'miss_distance': {'astronomical': '0.3631849099',
#      'lunar': '141.2789299511',
#      'kilometers': '54331688.937181913',
#      'miles': '33760146.0267918794'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1941-10-28',
#     'close_approach_date_full': '1941-Oct-28 20:01',
#     'epoch_date_close_approach': -889156740000,
#     'relative_velocity': {'kilometers_per_second': '28.5048252424',
#      'kilometers_per_hour': '102617.3708725558',
#      'miles_per_hour': '63762.4435846722'},
#     'miss_distance': {'astronomical': '0.4024547441',
#      'lunar': '156.5548954549',
#      'kilometers': '60206372.488755067',
#      'miles': '37410505.1163392446'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1943-11-10',
#     'close_approach_date_full': '1943-Nov-10 14:46',
#     'epoch_date_close_approach': -824980440000,
#     'relative_velocity': {'kilometers_per_second': '16.9141004389',
#      'kilometers_per_hour': '60890.7615799464',
#      'miles_per_hour': '37835.1512717173'},
#     'miss_distance': {'astronomical': '0.1750149399',
#      'lunar': '68.0808116211',
#      'kilometers': '26181862.227218013',
#      'miles': '16268654.8004460594'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1945-11-21',
#     'close_approach_date_full': '1945-Nov-21 04:38',
#     'epoch_date_close_approach': -760908120000,
#     'relative_velocity': {'kilometers_per_second': '29.5904924066',
#      'kilometers_per_hour': '106525.7726638925',
#      'miles_per_hour': '66190.9724644059'},
#     'miss_distance': {'astronomical': '0.4669642494',
#      'lunar': '181.6490930166',
#      'kilometers': '69856857.076388778',
#      'miles': '43407038.1761620164'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1946-10-25',
#     'close_approach_date_full': '1946-Oct-25 17:31',
#     'epoch_date_close_approach': -731658540000,
#     'relative_velocity': {'kilometers_per_second': '24.432629929',
#      'kilometers_per_hour': '87957.4677442546',
#      'miles_per_hour': '54653.3498880897'},
#     'miss_distance': {'astronomical': '0.2971319237',
#      'lunar': '115.5843183193',
#      'kilometers': '44450302.894522519',
#      'miles': '27620137.4558640022'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1948-11-17',
#     'close_approach_date_full': '1948-Nov-17 04:33',
#     'epoch_date_close_approach': -666559620000,
#     'relative_velocity': {'kilometers_per_second': '17.1668035168',
#      'kilometers_per_hour': '61800.4926603295',
#      'miles_per_hour': '38400.4227866364'},
#     'miss_distance': {'astronomical': '0.1852329781',
#      'lunar': '72.0556284809',
#      'kilometers': '27710458.977516647',
#      'miles': '17218480.7770658486'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1951-10-24',
#     'close_approach_date_full': '1951-Oct-24 17:44',
#     'epoch_date_close_approach': -573977760000,
#     'relative_velocity': {'kilometers_per_second': '20.8493213877',
#      'kilometers_per_hour': '75057.5569957999',
#      'miles_per_hour': '46637.8470121958'},
#     'miss_distance': {'astronomical': '0.2089649453',
#      'lunar': '81.2873637217',
#      'kilometers': '31260710.721546511',
#      'miles': '19424504.9161074118'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1953-11-23',
#     'close_approach_date_full': '1953-Nov-23 15:31',
#     'epoch_date_close_approach': -508235340000,
#     'relative_velocity': {'kilometers_per_second': '18.158142714',
#      'kilometers_per_hour': '65369.3137705098',
#      'miles_per_hour': '40617.9494370148'},
#     'miss_distance': {'astronomical': '0.2035818197',
#      'lunar': '79.1933278633',
#      'kilometers': '30455406.597844039',
#      'miles': '18924112.1371601782'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1956-10-26',
#     'close_approach_date_full': '1956-Oct-26 04:08',
#     'epoch_date_close_approach': -416001120000,
#     'relative_velocity': {'kilometers_per_second': '18.3872389433',
#      'kilometers_per_hour': '66194.0601959498',
#      'miles_per_hour': '41130.4147923112'},
#     'miss_distance': {'astronomical': '0.1611803955',
#      'lunar': '62.6991738495',
#      'kilometers': '24112243.852557585',
#      'miles': '14982653.575101273'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1958-11-26',
#     'close_approach_date_full': '1958-Nov-26 22:53',
#     'epoch_date_close_approach': -350183220000,
#     'relative_velocity': {'kilometers_per_second': '20.5107699545',
#      'kilometers_per_hour': '73838.7718360492',
#      'miles_per_hour': '45880.5413111273'},
#     'miss_distance': {'astronomical': '0.251583608',
#      'lunar': '97.866023512',
#      'kilometers': '37636371.88371496',
#      'miles': '23386157.058028048'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1961-11-01',
#     'close_approach_date_full': '1961-Nov-01 03:25',
#     'epoch_date_close_approach': -257718900000,
#     'relative_velocity': {'kilometers_per_second': '17.2274110587',
#      'kilometers_per_hour': '62018.6798114161',
#      'miles_per_hour': '38535.9957972658'},
#     'miss_distance': {'astronomical': '0.1584782007',
#      'lunar': '61.6480200723',
#      'kilometers': '23708001.266152509',
#      'miles': '14731468.8794982642'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1963-11-26',
#     'close_approach_date_full': '1963-Nov-26 06:09',
#     'epoch_date_close_approach': -192477060000,
#     'relative_velocity': {'kilometers_per_second': '24.3050531236',
#      'kilometers_per_hour': '87498.1912449161',
#      'miles_per_hour': '54367.9733321535'},
#     'miss_distance': {'astronomical': '0.338382038',
#      'lunar': '131.630612782',
#      'kilometers': '50621232.13105906',
#      'miles': '31454575.078212628'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1964-10-29',
#     'close_approach_date_full': '1964-Oct-29 17:57',
#     'epoch_date_close_approach': -163231380000,
#     'relative_velocity': {'kilometers_per_second': '29.5242153089',
#      'kilometers_per_hour': '106287.1751119763',
#      'miles_per_hour': '66042.7172244388'},
#     'miss_distance': {'astronomical': '0.4289776364',
#      'lunar': '166.8723005596',
#      'kilometers': '64174140.683074468',
#      'miles': '39875961.9475369384'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1966-11-09',
#     'close_approach_date_full': '1966-Nov-09 02:18',
#     'epoch_date_close_approach': -99265320000,
#     'relative_velocity': {'kilometers_per_second': '16.9317089153',
#      'kilometers_per_hour': '60954.1520952352',
#      'miles_per_hour': '37874.539672731'},
#     'miss_distance': {'astronomical': '0.172343208',
#      'lunar': '67.041507912',
#      'kilometers': '25782176.82576696',
#      'miles': '16020301.808265648'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1968-11-21',
#     'close_approach_date_full': '1968-Nov-21 17:45',
#     'epoch_date_close_approach': -35014500000,
#     'relative_velocity': {'kilometers_per_second': '28.9401164157',
#      'kilometers_per_hour': '104184.4190966298',
#      'miles_per_hour': '64736.1464103476'},
#     'miss_distance': {'astronomical': '0.4509833605',
#      'lunar': '175.4325272345',
#      'kilometers': '67466150.136242135',
#      'miles': '41921521.767866063'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1969-10-26',
#     'close_approach_date_full': '1969-Oct-26 00:16',
#     'epoch_date_close_approach': -5787840000,
#     'relative_velocity': {'kilometers_per_second': '24.9399777575',
#      'kilometers_per_hour': '89783.9199271105',
#      'miles_per_hour': '55788.2362458204'},
#     'miss_distance': {'astronomical': '0.3101459479',
#      'lunar': '120.6467737331',
#      'kilometers': '46397173.194970973',
#      'miles': '28829866.5646785074'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1971-11-17',
#     'close_approach_date_full': '1971-Nov-17 08:13',
#     'epoch_date_close_approach': 59213580000,
#     'relative_velocity': {'kilometers_per_second': '17.1385421826',
#      'kilometers_per_hour': '61698.7518573046',
#      'miles_per_hour': '38337.2050082235'},
#     'miss_distance': {'astronomical': '0.1841946474',
#      'lunar': '71.6517178386',
#      'kilometers': '27555126.916441038',
#      'miles': '17121961.9099528044'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1974-10-24',
#     'close_approach_date_full': '1974-Oct-24 15:00',
#     'epoch_date_close_approach': 151858800000,
#     'relative_velocity': {'kilometers_per_second': '21.0857347806',
#      'kilometers_per_hour': '75908.6452100912',
#      'miles_per_hour': '47166.6801306814'},
#     'miss_distance': {'astronomical': '0.2138218788',
#      'lunar': '83.1767108532',
#      'kilometers': '31987297.627878156',
#      'miles': '19875985.0842883128'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1976-11-23',
#     'close_approach_date_full': '1976-Nov-23 05:17',
#     'epoch_date_close_approach': 217574220000,
#     'relative_velocity': {'kilometers_per_second': '18.0786083386',
#      'kilometers_per_hour': '65082.9900190061',
#      'miles_per_hour': '40440.038992643'},
#     'miss_distance': {'astronomical': '0.202178501',
#      'lunar': '78.647436889',
#      'kilometers': '30245473.10939287',
#      'miles': '18793665.516326806'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1979-10-26',
# ...
#     'epoch_date_close_approach': 7255033380000,
#     'relative_velocity': {'kilometers_per_second': '20.2895063036',
#      'kilometers_per_hour': '73042.2226930756',
#      'miles_per_hour': '45385.5966505946'},
#     'miss_distance': {'astronomical': '0.4972420318',
#      'lunar': '193.4271503702',
#      'kilometers': '74386348.831752266',
#      'miles': '46221533.8430466308'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '154',
#    'orbit_determination_date': '2021-04-13 16:13:04',
#    'first_observation_date': '2001-08-05',
#    'last_observation_date': '2020-08-19',
#    'data_arc_in_days': 6954,
#    'observations_used': 578,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.192458',
#    'jupiter_tisserand_invariant': '5.061',
#    'epoch_osculation': '2459600.5',
#    'eccentricity': '.3606398761081319',
#    'semi_major_axis': '1.235387292484026',
#    'inclination': '20.92812488365864',
#    'ascending_node_longitude': '172.0600902444407',
#    'orbital_period': '501.5371659103095',
#    'perihelion_distance': '.7898573723770265',
#    'perihelion_argument': '343.9892963247323',
#    'aphelion_distance': '1.680917212591026',
#    'perihelion_time': '2459453.288386158205',
#    'mean_anomaly': '105.6675049930867',
#    'mean_motion': '.7177932653237891',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2111253?api_key=y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW'},
#   'id': '2111253',
#   'neo_reference_id': '2111253',
#   'name': '111253 (2001 XU10)',
#   'designation': '111253',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2111253',
#   'absolute_magnitude_h': 15.2,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 2.424124811,
#     'estimated_diameter_max': 5.4205078634},
#    'meters': {'estimated_diameter_min': 2424.124811008,
#     'estimated_diameter_max': 5420.5078633577},
#    'miles': {'estimated_diameter_min': 1.5062808579,
#     'estimated_diameter_max': 3.3681463916},
#    'feet': {'estimated_diameter_min': 7953.1656449475,
#     'estimated_diameter_max': 17783.8190184186}},
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_data': [{'close_approach_date': '1903-08-08',
#     'close_approach_date_full': '1903-Aug-08 08:58',
#     'epoch_date_close_approach': -2095426920000,
#     'relative_velocity': {'kilometers_per_second': '24.3059901248',
#      'kilometers_per_hour': '87501.5644492681',
#      'miles_per_hour': '54370.0693101577'},
#     'miss_distance': {'astronomical': '0.1083092356',
#      'lunar': '42.1322926484',
#      'kilometers': '16202830.947088172',
#      'miles': '10067972.2924418936'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1910-07-29',
#     'close_approach_date_full': '1910-Jul-29 02:34',
#     'epoch_date_close_approach': -1875389160000,
#     'relative_velocity': {'kilometers_per_second': '24.4253954836',
#      'kilometers_per_hour': '87931.4237409744',
#      'miles_per_hour': '54637.1671572738'},
#     'miss_distance': {'astronomical': '0.0839944554',
#      'lunar': '32.6738431506',
#      'kilometers': '12565391.619649998',
#      'miles': '7807772.3012380524'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1917-07-17',
#     'close_approach_date_full': '1917-Jul-17 21:13',
#     'epoch_date_close_approach': -1655434020000,
#     'relative_velocity': {'kilometers_per_second': '25.8368853959',
#      'kilometers_per_hour': '93012.7874253257',
#      'miles_per_hour': '57794.5289421419'},
#     'miss_distance': {'astronomical': '0.2819483007',
#      'lunar': '109.6778889723',
#      'kilometers': '42178865.234839509',
#      'miles': '26208731.5418988642'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1924-07-06',
#     'close_approach_date_full': '1924-Jul-06 08:23',
#     'epoch_date_close_approach': -1435505820000,
#     'relative_velocity': {'kilometers_per_second': '28.4220997491',
#      'kilometers_per_hour': '102319.5590966228',
#      'miles_per_hour': '63577.3949286766'},
#     'miss_distance': {'astronomical': '0.4849022456',
#      'lunar': '188.6269735384',
#      'kilometers': '72540343.099976872',
#      'miles': '45074479.0709579536'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1961-08-26',
#     'close_approach_date_full': '1961-Aug-26 07:54',
#     'epoch_date_close_approach': -263491560000,
#     'relative_velocity': {'kilometers_per_second': '26.8327104187',
#      'kilometers_per_hour': '96597.7575072563',
#      'miles_per_hour': '60022.0899355504'},
#     'miss_distance': {'astronomical': '0.4375705417',
#      'lunar': '170.2149407213',
#      'kilometers': '65459621.013066179',
#      'miles': '40674722.3855801102'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1968-08-15',
#     'close_approach_date_full': '1968-Aug-15 14:13',
#     'epoch_date_close_approach': -43494420000,
#     'relative_velocity': {'kilometers_per_second': '24.9489496993',
#      'kilometers_per_hour': '89816.2189175999',
#      'miles_per_hour': '55808.3055824387'},
#     'miss_distance': {'astronomical': '0.2486319951',
#      'lunar': '96.7178460939',
#      'kilometers': '37194816.880810437',
#      'miles': '23111787.5019085506'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1975-08-05',
#     'close_approach_date_full': '1975-Aug-05 22:44',
#     'epoch_date_close_approach': 176510640000,
#     'relative_velocity': {'kilometers_per_second': '24.2049066265',
#      'kilometers_per_hour': '87137.6638552636',
#      'miles_per_hour': '54143.9556327331'},
#     'miss_distance': {'astronomical': '0.0634912828',
#      'lunar': '24.6981090092',
#      'kilometers': '9498160.670447636',
#      'miles': '5901883.3666479368'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1982-07-27',
#     'close_approach_date_full': '1982-Jul-27 13:49',
#     'epoch_date_close_approach': 396625740000,
#     'relative_velocity': {'kilometers_per_second': '24.5627872456',
#      'kilometers_per_hour': '88426.0340843036',
#      'miles_per_hour': '54944.4987897719'},
#     'miss_distance': {'astronomical': '0.1140098968',
#      'lunar': '44.3498498552',
#      'kilometers': '17055637.720199816',
#      'miles': '10597881.8490208208'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1989-07-17',
#     'close_approach_date_full': '1989-Jul-17 07:29',
#     'epoch_date_close_approach': 616663740000,
#     'relative_velocity': {'kilometers_per_second': '25.9996998915',
#      'kilometers_per_hour': '93598.9196093467',
#      'miles_per_hour': '58158.7286872632'},
#     'miss_distance': {'astronomical': '0.2948387925',
#      'lunar': '114.6922902825',
#      'kilometers': '44107255.351371975',
#      'miles': '27406977.596904255'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '1996-07-06',
#     'close_approach_date_full': '1996-Jul-06 21:00',
#     'epoch_date_close_approach': 836686800000,
#     'relative_velocity': {'kilometers_per_second': '28.3894916068',
#      'kilometers_per_hour': '102202.1697846341',
#      'miles_per_hour': '63504.4537753467'},
#     'miss_distance': {'astronomical': '0.4774567727',
#      'lunar': '185.7306845803',
#      'kilometers': '71426516.212994149',
#      'miles': '44382379.1364872962'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2033-08-29',
#     'close_approach_date_full': '2033-Aug-29 02:11',
#     'epoch_date_close_approach': 2008894260000,
#     'relative_velocity': {'kilometers_per_second': '27.3718704029',
#      'kilometers_per_hour': '98538.7334506052',
#      'miles_per_hour': '61228.1369043497'},
#     'miss_distance': {'astronomical': '0.4808171318',
#      'lunar': '187.0378642702',
#      'kilometers': '71929218.776789266',
#      'miles': '44694744.0250772308'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2040-08-18',
#     'close_approach_date_full': '2040-Aug-18 02:32',
#     'epoch_date_close_approach': 2228869920000,
#     'relative_velocity': {'kilometers_per_second': '25.243175226',
#      'kilometers_per_hour': '90875.4308136828',
#      'miles_per_hour': '56466.4586630908'},
#     'miss_distance': {'astronomical': '0.2894089562',
#      'lunar': '112.5800839618',
#      'kilometers': '43294963.406443294',
#      'miles': '26902242.7871896972'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2047-08-08',
#     'close_approach_date_full': '2047-Aug-08 10:14',
#     'epoch_date_close_approach': 2448872040000,
#     'relative_velocity': {'kilometers_per_second': '24.2651165472',
#      'kilometers_per_hour': '87354.4195698491',
#      'miles_per_hour': '54278.6392043876'},
#     'miss_distance': {'astronomical': '0.1027891649',
#      'lunar': '39.9849851461',
#      'kilometers': '15377040.128118763',
#      'miles': '9554849.6713464094'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2054-07-29',
#     'close_approach_date_full': '2054-Jul-29 17:18',
#     'epoch_date_close_approach': 2668958280000,
#     'relative_velocity': {'kilometers_per_second': '24.4354177774',
#      'kilometers_per_hour': '87967.5039987761',
#      'miles_per_hour': '54659.5860263506'},
#     'miss_distance': {'astronomical': '0.0797802824',
#      'lunar': '31.0345298536',
#      'kilometers': '11934960.315038488',
#      'miles': '7416040.4533996144'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2061-07-19',
#     'close_approach_date_full': '2061-Jul-19 00:53',
#     'epoch_date_close_approach': 2888959980000,
#     'relative_velocity': {'kilometers_per_second': '25.7663457095',
#      'kilometers_per_hour': '92758.8445541809',
#      'miles_per_hour': '57636.7387175687'},
#     'miss_distance': {'astronomical': '0.2660753345',
#      'lunar': '103.5033051205',
#      'kilometers': '39804303.300737515',
#      'miles': '24733247.175167107'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2068-07-08',
#     'close_approach_date_full': '2068-Jul-08 12:26',
#     'epoch_date_close_approach': 3108975960000,
#     'relative_velocity': {'kilometers_per_second': '28.0443493571',
#      'kilometers_per_hour': '100959.657685439',
#      'miles_per_hour': '62732.4050768218'},
#     'miss_distance': {'astronomical': '0.4503675772',
#      'lunar': '175.1929875308',
#      'kilometers': '67374030.266180564',
#      'miles': '41864281.1348932232'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2112-08-21',
#     'close_approach_date_full': '2112-Aug-21 23:49',
#     'epoch_date_close_approach': 4501266540000,
#     'relative_velocity': {'kilometers_per_second': '25.6248876969',
#      'kilometers_per_hour': '92249.5957090193',
#      'miles_per_hour': '57320.311289307'},
#     'miss_distance': {'astronomical': '0.3366684302',
#      'lunar': '130.9640193478',
#      'kilometers': '50364880.054163674',
#      'miles': '31295285.2839957412'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2119-08-11',
#     'close_approach_date_full': '2119-Aug-11 22:42',
#     'epoch_date_close_approach': 4721236920000,
#     'relative_velocity': {'kilometers_per_second': '24.3644108157',
#      'kilometers_per_hour': '87711.8789364167',
#      'miles_per_hour': '54500.7505535751'},
#     'miss_distance': {'astronomical': '0.1438830586',
#      'lunar': '55.9705097954',
#      'kilometers': '21524599.095645182',
#      'miles': '13374765.6819082316'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2126-08-01',
#     'close_approach_date_full': '2126-Aug-01 12:32',
#     'epoch_date_close_approach': 4941261120000,
#     'relative_velocity': {'kilometers_per_second': '24.3631893612',
#      'kilometers_per_hour': '87707.4817001976',
#      'miles_per_hour': '54498.0182819922'},
#     'miss_distance': {'astronomical': '0.054271861',
#      'lunar': '21.111753929',
#      'kilometers': '8118954.80653607',
#      'miles': '5044884.582374966'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2133-07-20',
#     'close_approach_date_full': '2133-Jul-20 17:30',
#     'epoch_date_close_approach': 5161167000000,
#     'relative_velocity': {'kilometers_per_second': '25.7357894059',
#      'kilometers_per_hour': '92648.8418611324',
#      'miles_per_hour': '57568.3873219908'},
#     'miss_distance': {'astronomical': '0.2551532262',
#      'lunar': '99.2546049918',
#      'kilometers': '38170379.163148194',
#      'miles': '23717973.7949213172'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2140-07-08',
#     'close_approach_date_full': '2140-Jul-08 14:55',
#     'epoch_date_close_approach': 5381045700000,
#     'relative_velocity': {'kilometers_per_second': '28.4018315269',
#      'kilometers_per_hour': '102246.5934967302',
#      'miles_per_hour': '63532.0569424544'},
#     'miss_distance': {'astronomical': '0.4675157144',
#      'lunar': '181.8636129016',
#      'kilometers': '69939355.065768328',
#      'miles': '43458300.0497178064'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2177-08-25',
#     'close_approach_date_full': '2177-Aug-25 19:57',
#     'epoch_date_close_approach': 6552820620000,
#     'relative_velocity': {'kilometers_per_second': '26.1981832475',
#      'kilometers_per_hour': '94313.4596911008',
#      'miles_per_hour': '58602.7161063954'},
#     'miss_distance': {'astronomical': '0.3962570855',
#      'lunar': '154.1440062595',
#      'kilometers': '59279215.963207885',
#      'miles': '36834396.765863413'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2184-08-14',
#     'close_approach_date_full': '2184-Aug-14 03:55',
#     'epoch_date_close_approach': 6772737300000,
#     'relative_velocity': {'kilometers_per_second': '24.5442760857',
#      'kilometers_per_hour': '88359.3939083576',
#      'miles_per_hour': '54903.0911760014'},
#     'miss_distance': {'astronomical': '0.1932922461',
#      'lunar': '75.1906837329',
#      'kilometers': '28916108.304075807',
#      'miles': '17967636.5297758566'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2191-08-03',
#     'close_approach_date_full': '2191-Aug-03 20:23',
#     'epoch_date_close_approach': 6992684580000,
#     'relative_velocity': {'kilometers_per_second': '24.2615382195',
#      'kilometers_per_hour': '87341.537590294',
#      'miles_per_hour': '54270.6348432579'},
#     'miss_distance': {'astronomical': '0.0330961824',
#      'lunar': '12.8744149536',
#      'kilometers': '4951118.392171488',
#      'miles': '3076482.3105150144'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2198-07-23',
#     'close_approach_date_full': '2198-Jul-23 04:19',
#     'epoch_date_close_approach': 7212601140000,
#     'relative_velocity': {'kilometers_per_second': '25.4028626623',
#      'kilometers_per_hour': '91450.305584266',
#      'miles_per_hour': '56823.6634892901'},
#     'miss_distance': {'astronomical': '0.2183542117',
#      'lunar': '84.9397883513',
#      'kilometers': '32665324.975849079',
#      'miles': '20297291.7420681302'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '271',
#    'orbit_determination_date': '2021-07-02 05:55:58',
#    'first_observation_date': '2000-02-08',
#    'last_observation_date': '2021-04-18',
#    'data_arc_in_days': 7740,
#    'observations_used': 1139,
#    'orbit_uncertainty': '0',
#    'minimum_orbit_intersection': '.0285726',
#    'jupiter_tisserand_invariant': '3.742',
#    'epoch_osculation': '2459600.5',
#    'eccentricity': '.4396623907197815',
#    'semi_major_axis': '1.75350829205558',
#    'inclination': '42.02906364990586',
#    'ascending_node_longitude': '310.15716701',
#    'orbital_period': '848.1255814929318',
#    'perihelion_distance': '.9825566442234628',
#    'perihelion_argument': '6.959640153945191',
#    'aphelion_distance': '2.524459939887697',
#    'perihelion_time': '2459605.683428706038',
#    'mean_anomaly': '357.7998136421153',
#    'mean_motion': '.4244654422123455',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False}]

# %%
pd.json_normalize(datos)
# Out:
#          id neo_reference_id                      name designation  \
# 0   2099799          2099799          99799 (2002 LJ3)       99799
# 1   2099907          2099907           99907 (1989 VA)       99907
# 2   2099935          2099935          99935 (2002 AV4)       99935
# 3   2099942          2099942  99942 Apophis (2004 MN4)       99942
# 4   2100004          2100004          100004 (1983 VA)      100004
# 5   2100085          2100085         100085 (1992 UY4)      100085
# 6   2100756          2100756         100756 (1998 FM5)      100756
# 7   2100926          2100926          100926 (1998 MQ)      100926
# 8   2101869          2101869          101869 (1999 MM)      101869
# 9   2101873          2101873         101873 (1999 NC5)      101873
# 10  2101955          2101955  101955 Bennu (1999 RQ36)      101955
# 11  2102873          2102873        102873 (1999 WK11)      102873
# 12  2103067          2103067       103067 (1999 XA143)      103067
# 13  2105140          2105140        105140 (2000 NL10)      105140
# 14  2105141          2105141        105141 (2000 NF11)      105141
# 15  2106538          2106538        106538 (2000 WK63)      106538
# 16  2106589          2106589       106589 (2000 WN107)      106589
# 17  2108519          2108519          108519 (2001 LF)      108519
# 18  2108906          2108906         108906 (2001 PL9)      108906
# 19  2111253          2111253        111253 (2001 XU10)      111253
#
#                                      nasa_jpl_url  absolute_magnitude_h  \
# 0   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2099799                 18.36
# 1   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2099907                 17.91
# 2   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2099935                 16.05
# 3   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2099942                 19.70
# 4   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2100004                 16.49
# 5   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2100085                 17.80
# 6   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2100756                 16.27
# 7   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2100926                 16.65
# 8   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2101869                 19.20
# 9   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2101873                 16.39
# 10  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2101955                 20.21
# 11  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2102873                 17.46
# 12  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2103067                 16.79
# 13  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2105140                 15.74
# 14  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2105141                 18.93
# 15  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2106538                 16.27
# 16  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2106589                 16.06
# 17  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2108519                 17.86
# 18  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2108906                 17.85
# 19  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2111253                 15.20
#
#     is_potentially_hazardous_asteroid  \
# 0                               False
# 1                               False
# 2                               False
# 3                                True
# 4                               False
# 5                                True
# 6                               False
# 7                               False
# 8                                True
# 9                               False
# 10                               True
# 11                              False
# 12                               True
# 13                              False
# 14                              False
# 15                              False
# 16                              False
# 17                              False
# 18                              False
# 19                               True
#
#                                   close_approach_data  is_sentry_object  \
# 0   [{'close_approach_date': '1912-08-21', 'close_...             False
# 1   [{'close_approach_date': '1900-10-23', 'close_...             False
# 2   [{'close_approach_date': '1901-05-01', 'close_...             False
# 3   [{'close_approach_date': '1905-12-26', 'close_...             False
# 4   [{'close_approach_date': '1901-04-26', 'close_...             False
# 5   [{'close_approach_date': '1906-10-07', 'close_...             False
# 6   [{'close_approach_date': '1906-03-28', 'close_...             False
# 7   [{'close_approach_date': '1910-10-22', 'close_...             False
# 8   [{'close_approach_date': '1902-07-10', 'close_...             False
# 9   [{'close_approach_date': '1931-01-20', 'close_...             False
# 10  [{'close_approach_date': '1900-06-15', 'close_...             False
# 11  [{'close_approach_date': '1924-06-19', 'close_...             False
# 12  [{'close_approach_date': '1965-01-19', 'close_...             False
# 13  [{'close_approach_date': '1901-07-09', 'close_...             False
# 14  [{'close_approach_date': '1900-07-06', 'close_...             False
# 15  [{'close_approach_date': '1904-09-07', 'close_...             False
# 16  [{'close_approach_date': '1913-04-08', 'close_...             False
# 17  [{'close_approach_date': '1934-06-25', 'close_...             False
# 18  [{'close_approach_date': '1902-05-13', 'close_...             False
# 19  [{'close_approach_date': '1903-08-08', 'close_...             False
#
#                                            links.self  ...  \
# 0   http://www.neowsapp.com/rest/v1/neo/2099799?ap...  ...
# 1   http://www.neowsapp.com/rest/v1/neo/2099907?ap...  ...
# 2   http://www.neowsapp.com/rest/v1/neo/2099935?ap...  ...
# 3   http://www.neowsapp.com/rest/v1/neo/2099942?ap...  ...
# 4   http://www.neowsapp.com/rest/v1/neo/2100004?ap...  ...
# 5   http://www.neowsapp.com/rest/v1/neo/2100085?ap...  ...
# 6   http://www.neowsapp.com/rest/v1/neo/2100756?ap...  ...
# 7   http://www.neowsapp.com/rest/v1/neo/2100926?ap...  ...
# 8   http://www.neowsapp.com/rest/v1/neo/2101869?ap...  ...
# 9   http://www.neowsapp.com/rest/v1/neo/2101873?ap...  ...
# 10  http://www.neowsapp.com/rest/v1/neo/2101955?ap...  ...
# 11  http://www.neowsapp.com/rest/v1/neo/2102873?ap...  ...
# 12  http://www.neowsapp.com/rest/v1/neo/2103067?ap...  ...
# 13  http://www.neowsapp.com/rest/v1/neo/2105140?ap...  ...
# 14  http://www.neowsapp.com/rest/v1/neo/2105141?ap...  ...
# 15  http://www.neowsapp.com/rest/v1/neo/2106538?ap...  ...
# 16  http://www.neowsapp.com/rest/v1/neo/2106589?ap...  ...
# 17  http://www.neowsapp.com/rest/v1/neo/2108519?ap...  ...
# 18  http://www.neowsapp.com/rest/v1/neo/2108906?ap...  ...
# 19  http://www.neowsapp.com/rest/v1/neo/2111253?ap...  ...
#
#     orbital_data.perihelion_argument  orbital_data.aphelion_distance  \
# 0                  249.8871315625245               1.865036956773831
# 1                  2.852426994334104               1.161521466854341
# 2                  322.9855782229163               2.721379551262293
# 3                  126.5959309724569               1.099285102884829
# 4                  13.73082831897464                4.41174071463651
# 5                  42.19802732385117               4.292907623003559
# 6                  312.0915499114358               3.521453877447373
# 7                  138.7921723786536               2.509655801664701
# 8                  268.7929700487981               2.616303708639021
# 9                  295.2421343075267               2.826872297166659
# 10                 66.22306084084298               1.355887651343651
# 11                  220.411437080375               3.127615950352816
# 12                 103.9959015947011               2.915451142753618
# 13                 281.6455698340428                1.66126037179997
# 14                 115.8757889205864               1.689719643331937
# 15                  41.6240318544334               4.273847687434402
# 16                 11.71262047388859               3.473902011710143
# 17                  343.847449269161               2.038085012642664
# 18                 343.9892963247323               1.680917212591026
# 19                 6.959640153945191               2.524459939887697
#
#     orbital_data.perihelion_time  orbital_data.mean_anomaly  \
# 0           2459690.576515417136          309.7723741696225
# 1           2459539.902339669994          96.07742488583008
# 2           2459842.849257094068          247.7401548347363
# 3           2459748.288907609831          195.6544178118983
# 4           2459528.207104928162          17.07362581983968
# 5           2459907.630711197488          289.8706978236357
# 6           2459586.920811968348          3.924565564559537
# 7           2459804.510778172138          275.5313693682061
# 8           2459733.666751692352          296.5844642133645
# 9           2460073.644608730677          198.6361316996797
# 10          2455439.141940872670           101.703952002457
# 11          2459230.320171712882          117.2087952476288
# 12          2459865.567344887693          255.6182540071517
# 13          2459610.757064559808          348.4356087061727
# 14          2459701.687819878642           301.129588010646
# 15          2458947.132397989372          170.7775701785792
# 16          2460112.242796536104          199.9086268026246
# 17          2459456.226611020416          70.02143093426515
# 18          2459453.288386158205          105.6675049930867
# 19          2459605.683428706038          357.7998136421153
#
#     orbital_data.mean_motion  orbital_data.equinox  \
# 0          .5576106668622577                 J2000
# 1          1.585497267759294                 J2000
# 2          .4632151404602409                 J2000
# 3          1.112029210081047                 J2000
# 4            .23617294345279                 J2000
# 5          .2283369901464215                 J2000
# 6          .2890132720315519                 J2000
# 7          .4140400393969484                 J2000
# 8          .4762114790720501                 J2000
# 9          .3410455605384945                 J2000
# 10         .8244613503320309                 J2000
# 11         .3166266400575438                 J2000
# 12         .3937933057618773                 J2000
# 13         1.127456225550288                 J2000
# 14          .581793461505141                 J2000
# 15         .2613805301227672                 J2000
# 16          .312835616409269                 J2000
# 17         .4853385051083383                 J2000
# 18         .7177932653237891                 J2000
# 19         .4244654422123455                 J2000
#
#     orbital_data.orbit_class.orbit_class_type  \
# 0                                         AMO
# 1                                         ATE
# 2                                         APO
# 3                                         ATE
# 4                                         APO
# 5                                         APO
# 6                                         APO
# 7                                         AMO
# 8                                         APO
# 9                                         AMO
# 10                                        APO
# 11                                        AMO
# 12                                        APO
# 13                                        ATE
# 14                                        AMO
# 15                                        APO
# 16                                        APO
# 17                                        AMO
# 18                                        APO
# 19                                        APO
#
#      orbital_data.orbit_class.orbit_class_description  \
# 0   Near-Earth asteroid orbits similar to that of ...
# 1   Near-Earth asteroid orbits similar to that of ...
# 2   Near-Earth asteroid orbits which cross the Ear...
# 3   Near-Earth asteroid orbits similar to that of ...
# 4   Near-Earth asteroid orbits which cross the Ear...
# 5   Near-Earth asteroid orbits which cross the Ear...
# 6   Near-Earth asteroid orbits which cross the Ear...
# 7   Near-Earth asteroid orbits similar to that of ...
# 8   Near-Earth asteroid orbits which cross the Ear...
# 9   Near-Earth asteroid orbits similar to that of ...
# 10  Near-Earth asteroid orbits which cross the Ear...
# 11  Near-Earth asteroid orbits similar to that of ...
# 12  Near-Earth asteroid orbits which cross the Ear...
# 13  Near-Earth asteroid orbits similar to that of ...
# 14  Near-Earth asteroid orbits similar to that of ...
# 15  Near-Earth asteroid orbits which cross the Ear...
# 16  Near-Earth asteroid orbits which cross the Ear...
# 17  Near-Earth asteroid orbits similar to that of ...
# 18  Near-Earth asteroid orbits which cross the Ear...
# 19  Near-Earth asteroid orbits which cross the Ear...
#
#            orbital_data.orbit_class.orbit_class_range name_limited
# 0                  1.017 AU < q (perihelion) < 1.3 AU          NaN
# 1   a (semi-major axis) < 1.0 AU; q (perihelion) >...          NaN
# 2   a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
# 3   a (semi-major axis) < 1.0 AU; q (perihelion) >...      Apophis
# 4   a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
# 5   a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
# 6   a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
# 7                  1.017 AU < q (perihelion) < 1.3 AU          NaN
# 8   a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
# 9                  1.017 AU < q (perihelion) < 1.3 AU          NaN
# 10  a (semi-major axis) > 1.0 AU; q (perihelion) <...        Bennu
# 11                 1.017 AU < q (perihelion) < 1.3 AU          NaN
# 12  a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
# 13  a (semi-major axis) < 1.0 AU; q (perihelion) >...          NaN
# 14                 1.017 AU < q (perihelion) < 1.3 AU          NaN
# 15  a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
# 16  a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
# 17                 1.017 AU < q (perihelion) < 1.3 AU          NaN
# 18  a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
# 19  a (semi-major axis) > 1.0 AU; q (perihelion) <...          NaN
#
# [20 rows x 44 columns]

# %%
url = 'https://api.nasa.gov/neo/rest/v1/neo/browse/'
api_key ='y8zWjcsWb7gpD8KNst9khzgRg2reNpMZiKa4rLeW'

start_date = datetime.strptime('1995-01-01','%Y-%m-%d') 
end_date = datetime.strptime('1995-02-28','%Y-%m-%d') 

parametros = {
    'api_key': api_key,
    '': start_date,
    '': end_date
}
