# %% [markdown]
# ## Reto 6: Lo que los científicos aman
#
# ### 1. Objetivos:
#     - Practicar las siguientes herramientas:
#         - Lectura de .csv
#         - `merge`
#         - Filtros con value_counts()
#         - Agrupaciones y reordenamientos
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# #### a) Lo que los científicos aman
#
# En este Reto vamos a obtener una lista de las películas que fueron mejor evaluadas por científicos para saber cuáles son sus favoritas. Vamos a realizar los siguientes pasos:
#
# 1. Lee los archivos para `movies`, `ratings` y `users`.
# 2. Agrega **solamente** la columna `occupation` al `DataFrame` `ratings`, para tener la información de las ocupaciones de los usuarios que realizaron los ratings.
# 3. Filtra tu tabla `ratings` para quedarte solamente con los ratings hechos por científicos.
# 4. Agrega **solamente** la columna `title` de la tabla `movies` a la tabla `ratings` para tener la información de los nombres de las películas que fueron evaluadas por científicos.
# 5. Filtra tu `DataFrame` para quedarte **solamente** con las películas que fueron evaluadas más de 50 veces.
# 6. Realiza una agrupación por película y computa el promedio de los ratings de cada película.
# 7. Ordena la `Serie` resultante descendentemente y asígnala  a la variable `mean_of_scientists_ratings_sorted`.
#
# > **Nota**: el paso #5 es un poco complejo. No te desesperes si no encuentras una solución rápidamente. ¡Pídele a la experta que te guíe para que puedas resolverlo sin que te explote la cabeza!

# %%
import pandas as pd

# %%
movies = pd.read_csv('../Ejemplo-02/movies.csv', sep="#", index_col=0)
ratings = pd.read_csv('../Ejemplo-02/ratings.csv', index_col= 0 )
users = pd.read_csv('../Ejemplo-02/users.csv', index_col= 0 )

# %%
def esta_en_lista(valor, lista):
    """ Función que valida si el valor indicado se encuentra en la lista """
    if valor in lista:
        return True
    else:
        return False

# %%
ratings_occupations = pd.merge(ratings, users, left_on="user_id", right_index=True)
ratings_occupations = ratings_occupations.drop(columns=["gender", "age", "cp"])
ratings_occupations = ratings_occupations[ ratings_occupations["occupation"] == 15 ]
ratings_occupations_movies = pd.merge(ratings_occupations, movies, left_on="movie_id", right_index=True)
ratings_occupations_movies = ratings_occupations_movies.drop(columns=["genres"])
evalutions = ratings_occupations_movies.groupby("movie_id").size().reset_index(name='evaluations').set_index("movie_id", drop=True)
evalutions_list = list(evalutions[ evalutions["evaluations"] > 50 ].index.values)
ratings_occupations_movies = ratings_occupations_movies[ ratings_occupations_movies["movie_id"].apply(esta_en_lista, args= (evalutions_list,) ) ]
ratings_occupations_movies
# Out:
#          movie_id  rating  timestamp  occupation                title
# user_id
# 3            3421       4  978298147          15  Animal House (1978)
# 3            3421       4  978298147          15  Animal House (1978)
# 3            3421       4  978298147          15  Animal House (1978)
# 3            3421       4  978298147          15  Animal House (1978)
# 3            3421       4  978298147          15  Animal House (1978)
# ...           ...     ...        ...         ...                  ...
# 5939         2303       4  957214137          15     Nashville (1975)
# 5939         2303       4  957214137          15     Nashville (1975)
# 5939         2303       4  957214137          15     Nashville (1975)
# 5939         2303       4  957214137          15     Nashville (1975)
# 5939         2303       4  957214137          15     Nashville (1975)
#
# [177372 rows x 5 columns]

# %%
ratings_occupations_movies
# Out:
#          movie_id  rating  timestamp  occupation                title
# user_id
# 3            3421       4  978298147          15  Animal House (1978)
# 3            3421       4  978298147          15  Animal House (1978)
# 3            3421       4  978298147          15  Animal House (1978)
# 3            3421       4  978298147          15  Animal House (1978)
# 3            3421       4  978298147          15  Animal House (1978)
# ...           ...     ...        ...         ...                  ...
# 5939         2303       4  957214137          15     Nashville (1975)
# 5939         2303       4  957214137          15     Nashville (1975)
# 5939         2303       4  957214137          15     Nashville (1975)
# 5939         2303       4  957214137          15     Nashville (1975)
# 5939         2303       4  957214137          15     Nashville (1975)
#
# [177372 rows x 5 columns]

# %%
mean_of_scientists_ratings_sorted = ratings_occupations_movies.groupby(["movie_id", "title"])["rating"].mean().reset_index(name='rating').set_index("movie_id", drop=True).sort_values("rating", ascending=False)
mean_of_scientists_ratings_sorted
# Out:
#                                                   title    rating
# movie_id
# 922       Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)  5.000000
# 3030                                     Yojimbo (1961)  4.875000
# 3498                            Midnight Express (1978)  4.833333
# 1949                      Man for All Seasons, A (1966)  4.714286
# 1945                           On the Waterfront (1954)  4.666667
# ...                                                 ...       ...
# 2701                              Wild Wild West (1999)  1.833333
# 2906                               Random Hearts (1999)  1.833333
# 2450                             Howard the Duck (1986)  1.800000
# 2643            Superman IV: The Quest for Peace (1987)  1.666667
# 3593                           Battlefield Earth (2000)  1.666667
#
# [1157 rows x 2 columns]

# %% [markdown]
# La celda de validación a continuación, considera que este reto es la culimnación de todo el módulo, así que presume tus resultados y hasta la vista!

# %%
def visualizar_lista(mean_of_scientists_ratings_sorted):
    import matplotlib.pyplot as plt
    import seaborn as sns

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_title('Ratings promedio de las películas más evaluadas por científicos')
    sns.barplot(mean_of_scientists_ratings_sorted, mean_of_scientists_ratings_sorted.index, ax=ax)
    ax.set(ylabel='Título', xlabel='Rating Promedio')
    
visualizar_lista(mean_of_scientists_ratings_sorted)
# Out:
# c:\users\hborda\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11420/1419558855.py in <module>
#       8     ax.set(ylabel='Título', xlabel='Rating Promedio')
#       9
# ---> 10 visualizar_lista(mean_of_scientists_ratings_sorted)
#
# ~\AppData\Local\Temp/ipykernel_11420/1419558855.py in visualizar_lista(mean_of_scientists_ratings_sorted)
#       5     fig, ax = plt.subplots(figsize=(10, 10))
#       6     ax.set_title('Ratings promedio de las películas más evaluadas por científicos')
# ----> 7     sns.barplot(mean_of_scientists_ratings_sorted, mean_of_scientists_ratings_sorted.index, ax=ax)
#       8     ax.set(ylabel='Título', xlabel='Rating Promedio')
#       9
#
# c:\users\hborda\miniconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\hborda\miniconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# c:\users\hborda\miniconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# c:\users\hborda\miniconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# c:\users\hborda\miniconda3\lib\site-packages\seaborn\_core.py in infer_orient(x, y, orient, require_numeric)
#    1309     """
#    1310
# -> 1311     x_type = None if x is None else variable_type(x)
#    1312     y_type = None if y is None else variable_type(y)
#    1313
#
# c:\users\hborda\miniconda3\lib\site-packages\seaborn\_core.py in variable_type(vector, boolean_type)
#    1227
#    1228     # Special-case all-na data, which is always "numeric"
# -> 1229     if pd.isna(vector).all():
#    1230         return "numeric"
#    1231
#
# c:\users\hborda\miniconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
