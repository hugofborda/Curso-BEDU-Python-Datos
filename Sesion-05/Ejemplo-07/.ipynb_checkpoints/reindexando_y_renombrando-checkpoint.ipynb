# %% [markdown]
# ## Ejemplo 7: Reindexando y renombrando columnas
#
# ### 1. Objetivos:
#     - Limpiar un poco más nuestro dataset asignándole un índice y nombres de columnas apropiadas
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# Limpiemos nuestro dataset hasta que esté justo como lo dejamos en el Ejemplo pasado:

# %%
import pandas as pd

# %%
df = pd.read_csv('../../Datasets/melbourne_housing-raw.csv')

# %%
df_2 = df.drop(columns=['BuildingArea', 'YearBuilt'])

# %%
df_2['Regionname'] = df_2['Regionname'].fillna('Unknown')

# %%
df_dropped = df_2.dropna(axis=0, how='any')

# %%
#df_dropped=pd.read_csv("../Ejemplo-06/melbourne_housing-nonans.csv")
#df_dropped

# %% [markdown]
# Ahora, tenemos dos situaciones:
#
# 1. La primera es que nuestro índice no coincide con el número de filas que tenemos. En este caso, dado que nuestro índice es secuencial y numérico, y no tiene ningún significado además de eso, nos convendría que reflejara la cantidad de filas que tenemos en nuestro dataset.
#
# Para lograr eso vamos a usar el método `reset_index()`:

# %%
df_dropped.reset_index()
# Out:
#        index        Suburb               Address  Rooms Type      Price  \
# 0          1    Abbotsford          85 Turner St      2    h  1480000.0
# 1          2    Abbotsford       25 Bloomburg St      2    h  1035000.0
# 2          4    Abbotsford          5 Charles St      3    h  1465000.0
# 3          5    Abbotsford      40 Federation La      3    h   850000.0
# 4          6    Abbotsford           55a Park St      4    h  1600000.0
# ...      ...           ...                   ...    ...  ...        ...
# 11641  19731    Whittlesea         30 Sherwin St      3    h   601000.0
# 11642  19734  Williamstown           87 Pasco St      3    h  1285000.0
# 11643  19737    Yarraville           2 Adeney St      2    h   750000.0
# 11644  19738    Yarraville       54 Pentland Pde      6    h  2450000.0
# 11645  19739    Yarraville  10/127 Somerville Rd      3    t   645000.0
#
#       Method        SellerG        Date  Distance  Postcode  Bedroom2  \
# ...

# %% [markdown]
# Nuestro índice ya está correcto, pero ahora tenemos un columna llamada `index` que contiene el índice original. Como no queremos guardar esos datos, agregamos la opción `drop=True` para eliminar el índice anterior:

# %%
df_dropped.reset_index(drop=True)
# Out:
#              Suburb               Address  Rooms Type      Price Method  \
# 0        Abbotsford          85 Turner St      2    h  1480000.0      S
# 1        Abbotsford       25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford          5 Charles St      3    h  1465000.0     SP
# 3        Abbotsford      40 Federation La      3    h   850000.0     PI
# 4        Abbotsford           55a Park St      4    h  1600000.0     VB
# ...             ...                   ...    ...  ...        ...    ...
# 11641    Whittlesea         30 Sherwin St      3    h   601000.0      S
# 11642  Williamstown           87 Pasco St      3    h  1285000.0      S
# 11643    Yarraville           2 Adeney St      2    h   750000.0     SP
# 11644    Yarraville       54 Pentland Pde      6    h  2450000.0     VB
# 11645    Yarraville  10/127 Somerville Rd      3    t   645000.0     SP
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %% [markdown]
# Guardemos nuestros cambios en otra variable:

# %%
df_dropped = df_dropped.reset_index(drop=True)

df_dropped
# Out:
#              Suburb               Address  Rooms Type      Price Method  \
# 0        Abbotsford          85 Turner St      2    h  1480000.0      S
# 1        Abbotsford       25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford          5 Charles St      3    h  1465000.0     SP
# 3        Abbotsford      40 Federation La      3    h   850000.0     PI
# 4        Abbotsford           55a Park St      4    h  1600000.0     VB
# ...             ...                   ...    ...  ...        ...    ...
# 11641    Whittlesea         30 Sherwin St      3    h   601000.0      S
# 11642  Williamstown           87 Pasco St      3    h  1285000.0      S
# 11643    Yarraville           2 Adeney St      2    h   750000.0     SP
# 11644    Yarraville       54 Pentland Pde      6    h  2450000.0     VB
# 11645    Yarraville  10/127 Somerville Rd      3    t   645000.0     SP
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %% [markdown]
# Ahora tenemos un problema con los nombres de las columnas: Tienen inconsistencias en la manera cómo están nombradas y algunas incluso tienen errores ortográficos. Vamos a cambiarles los nombres para tener consistencia haciendo uso de la función `df.rename(columns=nuevos_nombres)`

# %%
nuevos_nombres = {
    'Suburb': 'suburb',
    'Address': 'address',
    'Rooms': 'rooms',
    'Type': 'type',
    'Price': 'price',
    'Method': 'method',
    'SellerG': 'seller_g',
    'Date': 'date',
    'Distance': 'distance',
    'Postcode': 'post_code',
    'Bedroom2': 'bedrooms',
    'Bathroom': 'bathroom',
    'Car': 'car',
    'Landsize': 'land_size',
    'CouncilArea': 'council_area',
    'Lattitude': 'latitude',
    'Longtitude': 'longitude',
    'Regionname': 'region_name',
    'Propertycount': 'property_count'
}

# %%
df_nuevo = df_dropped.rename(columns=nuevos_nombres)

df_nuevo
# Out:
#              suburb               address  rooms type      price method  \
# 0        Abbotsford          85 Turner St      2    h  1480000.0      S
# 1        Abbotsford       25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford          5 Charles St      3    h  1465000.0     SP
# 3        Abbotsford      40 Federation La      3    h   850000.0     PI
# 4        Abbotsford           55a Park St      4    h  1600000.0     VB
# ...             ...                   ...    ...  ...        ...    ...
# 11641    Whittlesea         30 Sherwin St      3    h   601000.0      S
# 11642  Williamstown           87 Pasco St      3    h  1285000.0      S
# 11643    Yarraville           2 Adeney St      2    h   750000.0     SP
# 11644    Yarraville       54 Pentland Pde      6    h  2450000.0     VB
# 11645    Yarraville  10/127 Somerville Rd      3    t   645000.0     SP
#
#             seller_g        date  distance  post_code  bedrooms  bathroom  \
# ...

# %% [markdown]
# Finalmente guardamos nuestros resultados en un archivos CSV:

# %%
df_nuevo.to_csv("melbourn_housing_clean.csv")

# %% [markdown]
# ¡Listo! Nuestro dataset va agarrando forma.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reto 7: Limpiando un dataset
#
# ### 1. Objetivos:
#     - Aplicar todo lo que aprendimos el día de hoy a un dataset real
#
# ### 2. Desarrollo:

# %% [markdown]
# #### a) Limpieza de datos en el mundo real
#
# Hasta ahora hemos estado realizando ejercicios con datasets dummy (falsos). Ahora vamos a aplicar todo lo que hemos aprendido el día de hoy a un dataset real.
#
# El dataset se encuentra en la carpeta [Datasets](../../Datasets/Readme.md) en la raíz del repositorio. El nombre el dataset es 'Datasets/new_york_times_bestsellers-raw.csv'.
#
# Lee el dataset usando pandas y realiza las siguientes tareas:
#
# 1. Ve a este el archivo `Readme.md` de la carpeta `Datasets` para conocer más sobre el dataset y los datos que contiene.
# 2. Explora tu dataset para entender su estructura
# 3. Identifica los `NaNs` en el dataset y dónde se encuentran
# 4. Elimina los `NaNs` de tu dataset
# 5. Resetea tu índice para que sea compatible con el nuevo dataset
# 6. Cambia los nombres de las columnas para que tengan consistencia y no haya errores ortográficos
# 7. Realiza agregaciones (min, man, mean, etc) de las siguientes columnas para conocer mejor la distribución de tus datos:
#
#    - a) rank
#    - b) rank_last_week
#    - c) week_in_list
#
# Si tienes dudas en algún momento, por favor pídele a la experta que te oriente. Todas las tareas que hay que realizar ya las hemos hecho en otros retos; puedes ir a revisar esos otros ejercicios para recordar.
#
# ¡Mucha suerte!

# %%
df = pd.read_csv('../../Datasets/new_york_times_bestsellers-raw.csv')
df
# Out:
#        Unnamed: 0                                 amazon_product_url  \
# 0               0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...
# 1               1  http://www.amazon.com/The-Host-Novel-Stephenie...
# 2               2  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 3               3  http://www.amazon.com/The-Front-Garano-Patrici...
# 4               4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# ...           ...                                                ...
# 10190       10190  https://www.amazon.com/Clancy-Line-Sight-Jack-...
# 10191       10191  https://www.amazon.com/Something-Water-Novel-C...
# 10192       10192  https://www.amazon.com/Little-Fires-Everywhere...
# 10193       10193  https://www.amazon.com/Shelter-Place-Nora-Robe...
# 10194       10194  https://www.amazon.com/Last-Time-Lied-Novel/dp...
#
#                    author                                        description  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                               0
# amazon_product_url                       0
# author                                   0
# description                            246
# publisher                                0
# title                                    0
# _id.$oid                                 0
# bestsellers_date.$date.$numberLong       0
# published_date.$date.$numberLong         0
# price.$numberInt                      3033
# rank.$numberInt                          0
# rank_last_week.$numberInt                0
# weeks_on_list.$numberInt                 0
# price.$numberDouble                   7162
# dtype: int64

# %%
df_1 = df.copy()
df_1
# Out:
#        Unnamed: 0                                 amazon_product_url  \
# 0               0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...
# 1               1  http://www.amazon.com/The-Host-Novel-Stephenie...
# 2               2  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 3               3  http://www.amazon.com/The-Front-Garano-Patrici...
# 4               4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# ...           ...                                                ...
# 10190       10190  https://www.amazon.com/Clancy-Line-Sight-Jack-...
# 10191       10191  https://www.amazon.com/Something-Water-Novel-C...
# 10192       10192  https://www.amazon.com/Little-Fires-Everywhere...
# 10193       10193  https://www.amazon.com/Shelter-Place-Nora-Robe...
# 10194       10194  https://www.amazon.com/Last-Time-Lied-Novel/dp...
#
#                    author                                        description  \
# ...

# %%
df_1["price.$numberDouble"] = df["price.$numberDouble"].fillna(0.0)
df_1["description"] = df["description"].fillna('')
df_1 = df_1.dropna(subset=["price.$numberInt"])
df_1 = df_1.drop(["Unnamed: 0"],axis=1)
df_1 = df_1.reset_index(drop=True)
df_1
# Out:
#                                      amazon_product_url              author  \
# 0     http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...       Dean R Koontz
# 1     http://www.amazon.com/Careless-Red-Novel-Eliza...        Troy Denning
# 2     http://www.amazon.com/Hold-Tight-Harlan-Coben/...         Jeff Shaara
# 3     http://www.amazon.com/Executive-Privilege-Nove...    Phillip Margolin
# 4     http://www.amazon.com/Unaccustomed-Vintage-Con...       Jhumpa Lahiri
# ...                                                 ...                 ...
# 7157  https://www.amazon.com/Clancy-Line-Sight-Jack-...          Mike Maden
# 7158  https://www.amazon.com/Something-Water-Novel-C...  Catherine Steadman
# 7159  https://www.amazon.com/Little-Fires-Everywhere...          Celeste Ng
# 7160  https://www.amazon.com/Shelter-Place-Nora-Robe...        Nora Roberts
# 7161  https://www.amazon.com/Last-Time-Lied-Novel/dp...         Riley Sager
#
# ...

# %%
df_1.isna().sum()
# Out:
# Unnamed: 0                            0
# amazon_product_url                    0
# author                                0
# description                           0
# publisher                             0
# title                                 0
# _id.$oid                              0
# bestsellers_date.$date.$numberLong    0
# published_date.$date.$numberLong      0
# price.$numberInt                      0
# rank.$numberInt                       0
# rank_last_week.$numberInt             0
# weeks_on_list.$numberInt              0
# price.$numberDouble                   0
# dtype: int64

# %%
df_1["rank.$numberInt"].min()
# Out:
# 1

# %%
df_1["rank.$numberInt"].max()
# Out:
# 20

# %%
df_1["rank.$numberInt"].mean()
# Out:
# 11.064507120915945

# %%
df_1["rank.$numberInt"].std()
# Out:
# 5.904019796463786

# %%
df_1["rank_last_week.$numberInt"].min()
# Out:
# 0

# %%
df_1["rank_last_week.$numberInt"].max()
# Out:
# 16

# %%
df_1["rank_last_week.$numberInt"].mean()
# Out:
# 3.5759564367495114

# %%
df_1["rank_last_week.$numberInt"].std()
# Out:
# 4.462119726782168

# %%
df_1["weeks_on_list.$numberInt"].min()
# Out:
# 0

# %%
df_1["weeks_on_list.$numberInt"].max()
# Out:
# 134

# %%
df_1["weeks_on_list.$numberInt"].mean()
# Out:
# 6.782462999162245

# %%
df_1["weeks_on_list.$numberInt"].std()
# Out:
# 15.059232662684694
